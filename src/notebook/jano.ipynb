# %% [markdown]
# # Data Challenge (Hackathon) - Bäckerei Umsatz
#
# ## 1. Problembeschreibung
#
# - Worum geht es?
# - Welche Daten werden verwendet?
#
# ### Daten
#
# Die Basis für diese Challenge bildet der Datensatz **Umsatz_Baeckerei.csv**. Der Datensatz enthält die täglichen Umsätze einer **Bäckereifiliale in Kiel** (Schleswig-Holstein) für 6 verschiedene Warengruppen:
#
# - 1 - Brot
# - 2 - Brötchen
# - 3 - Croissants
# - 4 - Konditorei
# - 5 - Kuchen
# - 6 - unbekannt
#
# **Hinweis:** Die Daten für Warengruppe 6 sind jedoch unvollständig und sollen im weiteren Verlauf nicht berücksichtigt werden. Um die Problemstellung einzugrenzen, betrachten wir für diese Challenge nur die beiden umsatzstärksten Warengruppen 2 (Brötchen) und 5 (Kuchen).
#
# Die Umsätze liegen im Zeitraum 01.07.2013 bis 30.07.2019 vor.
# - Die Daten für die Jahre 2013 bis 2017 können als **Trainingsdaten** verwendet werden.
# - Die Daten für 2018 sind als **Testdaten** reserviert.
# - Die Daten für 2019 werden nicht verwendet.
#
# ### Ziel
#
# Das Ziel der Challenge ist es, das beste Prognosemodell für die Warengruppen 2 (Brötchen) und 5 (Kuchen) zu finden.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
# CSV-Datei einlesen
df = pd.read_csv("../../data/raw/Umsatz_Baeckerei.csv")

# Ersten Zeilen anzeigen
df.head()
# Out:
#         Datum  Warengruppe      Umsatz
# 0  2013-07-01            1  148.828353
# 1  2013-07-02            1  159.793757
# 2  2013-07-03            1  111.885594
# 3  2013-07-04            1  168.864941
# 4  2013-07-05            1  171.280754

# %%
# Überblick über den Datensatz
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11164 entries, 0 to 11163
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Datum        11164 non-null  object
#  1   Warengruppe  11164 non-null  int64
#  2   Umsatz       11164 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 261.8+ KB

# %%
# Formatierung anpassen
df["Datum"] = pd.to_datetime(df["Datum"])
df["Umsatz"] = df["Umsatz"].round(2)
df.head()
# Out:
#        Datum  Warengruppe  Umsatz
# 0 2013-07-01            1  148.83
# 1 2013-07-02            1  159.79
# 2 2013-07-03            1  111.89
# 3 2013-07-04            1  168.86
# 4 2013-07-05            1  171.28

# %%
# Datensatz auf Warengruppen 2 und 5 einschränken
df = df[df["Warengruppe"].isin([2, 5])].copy()

# Spalte umbenennen
df = df.rename(columns={"Warengruppe": "Warengruppe_num"})

# Textuelle Warengruppen ergänzen
warengruppe_mapping = {
    2: "Brötchen",
    5: "Kuchen"
}

df["Warengruppe_text"] = df["Warengruppe_num"].map(warengruppe_mapping)

# Datumsgrenze definieren
stichtag = pd.to_datetime("2019-01-01")

# Datensatz auf Daten vor dem gewählten Stichtag filtern
df = df[df["Datum"] < stichtag].copy()

# Ergebnis prüfen
df.head()
# Out:
#           Datum  Warengruppe_num  Umsatz Warengruppe_text
# 2174 2013-07-01                2  535.86         Brötchen
# 2175 2013-07-02                2  546.78         Brötchen
# 2176 2013-07-03                2  427.34         Brötchen
# 2177 2013-07-04                2  454.86         Brötchen
# 2178 2013-07-05                2  492.82         Brötchen

# %%
# Extremwerte in H1 2014 glätten (Capping auf IQR-basierte Obergrenze)
# Betroffener Zeitraum: 01.01.2014 – 30.06.2014
# Besonders auffällig: 05.05.2014 mit Brötchen=1203 EUR, Kuchen=749 EUR

h1_2014_mask = (df["Datum"] >= "2014-01-01") & (df["Datum"] <= "2014-06-30")

for wg in df["Warengruppe_text"].unique():
    wg_mask = df["Warengruppe_text"] == wg

    # Obergrenze auf Basis der Gesamtdaten berechnen (Q75 + 1.5 * IQR)
    q25 = df.loc[wg_mask, "Umsatz"].quantile(0.25)
    q75 = df.loc[wg_mask, "Umsatz"].quantile(0.75)
    iqr = q75 - q25
    upper_bound = q75 + 1.5 * iqr

    # Nur in H1 2014: Werte über der Obergrenze auf die Obergrenze setzen
    clip_mask = h1_2014_mask & wg_mask & (df["Umsatz"] > upper_bound)
    n_clipped = clip_mask.sum()
    print(f"{wg}: {n_clipped} Werte gekappt auf {upper_bound:.2f} EUR")
    df.loc[clip_mask, "Umsatz"] = upper_bound

print(f"\nGesamt: {df.loc[h1_2014_mask].shape[0]} Datensätze in H1 2014")
# Out:
# Brötchen: 3 Werte gekappt auf 792.38 EUR
# Kuchen: 6 Werte gekappt auf 427.63 EUR
#
# Gesamt: 352 Datensätze in H1 2014
#
# Kuchen: 6 Werte gekappt auf 427.63 EUR
#
# Gesamt: 352 Datensätze in H1 2014

# %% [markdown]
# ## 2. Explorative Datenanalyse / Aufbereitung des Datensatzes
#
# - Was steckt in den Daten? (explorative Datenanalyse, Visualisierung der Erkenntnisse)
# - Welche Besonderheiten gibt es? (Outlier, Missing Values,…)
# - Wie werden die Daten aufbereitet? (Anreicherung mit externen Daten, Feature Engineering,…)
# - Welche Features werden verwendet?
# - Wie ist die Aufteilung der Daten? (Train/Test Split, optional: Evaluation Data)

# %%
# Grundlegender Überblick
print("Shape des Datensatzes:")
print(df.shape)

print("\nDatentypen:")
print(df.dtypes)

print("\nStatistische Kennzahlen je Warengruppe:")
display(
    df.groupby("Warengruppe_text")["Umsatz"].describe()
)

# Missing Values
print("\nFehlende Werte pro Spalte:")
print(df.isnull().sum())

print("\nAnzahl der Datensätze mit Umsatz = 0 je Warengruppe:")
print(
    df[df["Umsatz"] == 0]
    .groupby("Warengruppe_text")
    .size()
)
# Out:
# Shape des Datensatzes:
# (3938, 4)
#
# Datentypen:
# Datum               datetime64[ns]
# Warengruppe_num              int64
# Umsatz                     float64
# Warengruppe_text            object
# dtype: object
#
# Statistische Kennzahlen je Warengruppe:
#                    count        mean         std     min     25%     50%  \
# Warengruppe_text
# Brötchen          1969.0  401.704068  136.829753  175.00  289.53  371.97
# Kuchen            1969.0  277.471204  101.274510  121.49  229.43  266.70
#
#                      75%      max
# Warengruppe_text
# Brötchen          490.67   930.80
# Kuchen            308.71  1879.46
# Fehlende Werte pro Spalte:
# Datum               0
# Warengruppe_num     0
# Umsatz              0
# Warengruppe_text    0
# dtype: int64
#
# Anzahl der Datensätze mit Umsatz = 0 je Warengruppe:
# Series([], dtype: int64)

# %% [markdown]
# Es gibt also keine fehlenden Werte. Das heißt, für jedes enthaltene Datum sind alle Spalten gefüllt.
#
# **ACHTUNG:** Trotzdem kann es Datümer gehen, die im Datensatz nicht auftauchen. Das sollten wir überprüfen!

# %%
# Fehlende Datümer in der Zeitreihe
pd.date_range(df["Datum"].min(), df["Datum"].max()).difference(df["Datum"])
# Out:
# DatetimeIndex(['2013-12-25', '2013-12-26', '2013-12-28', '2014-01-01',
#                '2014-04-18', '2014-05-01', '2014-05-03', '2014-05-04',
#                '2014-08-17', '2014-12-25', '2014-12-26', '2015-01-01',
#                '2015-04-03', '2015-05-01', '2015-12-25', '2015-12-26',
#                '2016-01-01', '2016-03-24', '2016-03-25', '2016-07-07',
#                '2016-07-18', '2016-08-14', '2016-08-15', '2016-12-17',
#                '2016-12-25', '2016-12-26', '2017-01-01', '2017-04-14',
#                '2017-05-01', '2017-07-04', '2017-10-23', '2017-10-31',
#                '2017-12-25', '2017-12-26', '2018-01-01', '2018-03-30',
#                '2018-05-01', '2018-05-21', '2018-10-31', '2018-12-25',
#                '2018-12-26'],
#               dtype='datetime64[ns]', freq=None)

# %%
'''
# Fehlende Tage füllen (Feiertage/geschlossen)
date_range = pd.date_range(df['Datum'].min(), df['Datum'].max(), freq='D')
df_filled = []
for wg in df['Warengruppe_num'].unique():
    df_wg = df[df['Warengruppe_num'] == wg].set_index('Datum').reindex(date_range)
    df_wg['ist_geschlossen'] = df_wg['Umsatz'].isna().astype(int)
    df_wg['Umsatz'] = df_wg['Umsatz'].fillna(0)
    df_wg['Warengruppe_num'] = wg
    # Populate Warengruppe_text
    wg_text = warengruppe_mapping.get(wg, None)
    df_wg['Warengruppe_text'] = wg_text
    df_filled.append(df_wg.reset_index().rename(columns={'index': 'Datum'}))
df = pd.concat(df_filled, ignore_index=True).sort_values(['Warengruppe_num', 'Datum']).reset_index(drop=True)

print(f"Geschlossene Tage gefüllt: {df['ist_geschlossen'].sum()}")
print(f"Keine Lücken mehr: {len(df[df['ist_geschlossen'] == 1])} Tage mit Umsatz=0")
'''
# Out:
# '\n# Fehlende Tage füllen (Feiertage/geschlossen)\ndate_range = pd.date_range(df[\'Datum\'].min(), df[\'Datum\'].max(), freq=\'D\')\ndf_filled = []\nfor wg in df[\'Warengruppe_num\'].unique():\n    df_wg = df[df[\'Warengruppe_num\'] == wg].set_index(\'Datum\').reindex(date_range)\n    df_wg[\'ist_geschlossen\'] = df_wg[\'Umsatz\'].isna().astype(int)\n    df_wg[\'Umsatz\'] = df_wg[\'Umsatz\'].fillna(0)\n    df_wg[\'Warengruppe_num\'] = wg\n    # Populate Warengruppe_text\n    wg_text = warengruppe_mapping.get(wg, None)\n    df_wg[\'Warengruppe_text\'] = wg_text\n    df_filled.append(df_wg.reset_index().rename(columns={\'index\': \'Datum\'}))\ndf = pd.concat(df_filled, ignore_index=True).sort_values([\'Warengruppe_num\', \'Datum\']).reset_index(drop=True)\n\nprint(f"Geschlossene Tage gefüllt: {df[\'ist_geschlossen\'].sum()}")\nprint(f"Keine Lücken mehr: {len(df[df[\'ist_geschlossen\'] == 1])} Tage mit Umsatz=0")\n'

# %% [markdown]
# ### Erkenntnisse aus der explorativen Datenanalyse (Teil 1)
#
# - Für beide Warengruppen (Brötchen und Kuchen) liegen je 1.969 Beobachtungen vor.
# - Es gibt zwar keine fehlenden Werte: Für jedes existierende Datum sind alle Spalten gefüllt.
# - Aber für einige Datümer liegen keine Umsatzdaten vor. Dabei handelt es sich auf den ersten Blick um Feiertage, an denen die Bäckereifiliale geschlossen war. Es sind also keine klassischen *missing values*.
# - Der durchschnittliche Umsatz für Brötchen (402 EUR / Tag) liegt über dem für Kuchen (278 EUR / Tag).
# - Bei beiden Warengruppen liegt der Mittelwert über dem Median, ein Hinweis auf eine rechtsschiefe Verteilungen (einige Tage mit sehr hohen Umsätzen).
# - Die Umsätze für Brötchen zeigen eine größere Volatilität (Streuung).
# - Die Umsätze für Kuchen zeigen extreme Ausreißer nach oben, trotz niedrigerem Durchschnitt, im Vergleich zu den Umsätzen für Brötchen. --> Das sollten wir genauer untersuchen! (Outlier?)
# - Beide Warengruppen haben relativ niedrige Mindestumsätze, ein Hinweis auf mögliche Sondertage (Feiertage, Schließungen, Datenartefakte).

# %%
# Zeitlicher Verlauf
plt.figure(figsize=(12, 5))
for wg in sorted(df["Warengruppe_text"].unique()):
    subset = df[df["Warengruppe_text"] == wg]
    plt.plot(subset["Datum"], subset["Umsatz"], label=f"WG {wg}", alpha=0.7)

plt.title("Täglicher Umsatz je Warengruppe")
plt.xlabel("Datum")
plt.ylabel("Umsatz")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Erkenntnisse aus der explorativen Datenanalyse (Teil 2)
#
# - Im zeitlichen Verlauf sehen wir saisonale Muster für beide Warengruppen.
# - Die Umsätze im Sommer scheinen tendenziell höher zu sein (Ferien?).
# - Die saisonalen Schwankungen sind für Brötchen stärker ausgeprägt im Vergleich zu Kuchen.
# - Die Umsätze für Kuchen zeigen Extremwerte zum Jahresende (Berliner?).
# - Es gibt einen ungewöhnlichen Peek für beide Warengruppen im Mai 2014 (--> Artefakt?!)

# %%
# Verteilungen & Outlier
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="Warengruppe_text", y="Umsatz")
plt.title("Umsatzverteilung je Warengruppe (Outlier-Erkennung)")
plt.tight_layout()
plt.show()

# Histogramm Umsatz
plt.figure(figsize=(10, 5))
sns.histplot(df["Umsatz"], bins=50, kde=True)
plt.title("Verteilung der Umsätze (Histogram)")
plt.xlabel("Umsatz")
plt.tight_layout()
plt.show()

# TOP5 umsatzstärkste Tage für die Warengruppe "Kuchen"
top5_kuchen = (
    df[df["Warengruppe_text"] == "Kuchen"]
    .sort_values(by="Umsatz", ascending=False)
    .head(5)
)

display(top5_kuchen[["Datum", "Umsatz"]])
# Out:
#            Datum   Umsatz
# 9179  2014-12-31  1879.46
# 9539  2015-12-31  1869.94
# 9895  2016-12-31  1705.14
# 10610 2018-12-31  1668.12
# 8822  2013-12-31  1625.69

# %% [markdown]
# ### Erkenntnisse aus der explorativen Datenanalyse (Teil 3)
#
# Analyse des **Boxplots**:
#
# - Ausgefüllte Box zeigt den Normalbereich der Umsätze (25% Quartil - 75% Quartil).
# - Die Linie innerhalb der ausgefüllten Box zeigt den Median (50%).
# - Die Whisker zeigen die Range für Werte bis 1,5 x IQR (Interquartilsbereich, also der Abstand zwischen 25% und 75% Quartil).
# - Punkte außerhalb der Whisker sind "Ausreißer".
#
# Analyse der **Umsatzverteilung**:
#
# -  Wir finden - wie erwartet - eine rechtsschiefe Verteilungen: Es gibt einige wenige Tage mit sehr hohen Umsätzen.
# - Die TOP5 umsatzstärksten Tage für Kuchen sind die Silvestertage. Hier spiegelt sich offenbar der Berliner-Verkauf wider. Das sollten wir für unsere Prognosemodelle im Hinterkopf behalten!

# %% [markdown]
# ## Anreicherung der Daten
#
# Es ist für diese Challenge zulässig, die originären Daten anzureichern. Es gibt verschiedene Arten, Daten anzureichern, z.B. auf Basis vorhandener Informationen oder mithilfe von externen Informationen.
#
# Beispiele für vorhandene Informationen sind:
# - Wochentag / Monat
# - Umsatz der Vortage (lag_1d, lag_2d, ...)
# - Umsatz des entsprechenden Wochentages der Vorwochen (lag_1W, lag_2W, ...)
# - Umsatz des entsprechenden Tages des Vorjahres (lag_1y)
# - Durchschnittlicher Umsatz der letzten 3 Tage (mean_3d)
# - ...
#
# Beispiele für externe Informationen könnten sein:
#
# - Schulferien (saisongeschäft vor allem im Sommer sichtbar mit starken Umsätzen)
# - Feiertage (vor allem Silvester)
# - (Groß-)Veranstaltungen (Kieler Woche)
# - Wetterdaten (Temperatur, Niederschlag, Sonnenscheindauer,...)
# - ...
#
# **Hinweise:**
#
# - Wenn Ihr die Daten anreichert, müsst Ihr sicherstellen, dass auch die Testdaten (Jahresscheibe 2018) entsprechend angereichert werden.
# - Und gebt unbedingt die Quellen für verwendete externe Daten an.
#
# ### Demo
#
# - Exemplarisch werden hier die Daten um eine einfache Dummy-Variable "Silvester" angereichert. Die Variable hat den Wert 1 an Silvester und 0 sonst.
# - Außerdem schaffen wir für die Wochentage (Montag - Sonntag) weitere Dummy-Variablen mit Ausprägung 0/1.
# - Und wir bilden den Umsatz des entsprechenden Wochentages der Vorwoche als neues numerisches Input Feature (lag_1W).

# %%
# 0/1-Variable "Silvester" erzeugen
df["Silvester"] = (
    (df["Datum"].dt.month == 12) &
    (df["Datum"].dt.day == 31)
).astype(int)

df.groupby("Warengruppe_text")["Silvester"].value_counts()
# Out:
# Warengruppe_text  Silvester
# Brötchen          0            1963
#                   1               6
# Kuchen            0            1963
#                   1               6
# Name: count, dtype: int64

# %%
# 0/1-Variable "Silvester" erzeugen
df["pre_Silvester"] = (
    (df["Datum"].dt.month == 12) &
    (df["Datum"].dt.day == 30)
).astype(int)

df.groupby("Warengruppe_text")["pre_Silvester"].value_counts()
# Out:
# Warengruppe_text  pre_Silvester
# Brötchen          0                1963
#                   1                   6
# Kuchen            0                1963
#                   1                   6
# Name: count, dtype: int64

# %%
# Wochentag als Text (Montag, Dienstag, ...)
df["Wochentag_num"] = df["Datum"].dt.weekday

wochentag_mapping = {
    0: "Montag",
    1: "Dienstag",
    2: "Mittwoch",
    3: "Donnerstag",
    4: "Freitag",
    5: "Samstag",
    6: "Sonntag"
}

df["Wochentag"] = df["Wochentag_num"].map(wochentag_mapping)

# Dummy-Variablen erzeugen
wochentag_dummies = pd.get_dummies(
    df["Wochentag"],
    prefix="WT",
    drop_first=False # <-- Brauche eigentlich nur 6 Wochentags-Variablen
)

# Dummies an Datensatz anhängen
df = pd.concat([df, wochentag_dummies], axis=1)

# Alle Wochentags-Dummies von bool → 0/1 umwandeln
wt_cols = [col for col in df.columns if col.startswith("WT_")]
df[wt_cols] = df[wt_cols].astype(int)

# %%
# ============================================================
# Externe Daten einlesen und als Features an df anhängen
# ============================================================
ext_path = "../../data/external_factors/"

# --- 1. Ferien (Schulferien Schleswig-Holstein) → Dummy 0/1 ---
df_ferien = pd.read_csv(ext_path + "ferien.csv")
df_ferien["Start"] = pd.to_datetime(df_ferien["Start"], errors="coerce")
df_ferien["Ende"] = pd.to_datetime(df_ferien["Ende"], errors="coerce")
df_ferien = df_ferien.dropna(subset=["Start", "Ende"])

ferien_tage = set()
for _, row in df_ferien.iterrows():
    ferien_tage.update(pd.date_range(row["Start"], row["Ende"]))

df["Ferien"] = df["Datum"].isin(ferien_tage).astype(int)
print(f"Ferien: {df['Ferien'].sum() // 2} Ferientage erkannt (je WG)")

# --- 2. Kieler Woche → Dummy 0/1 ---
df_kw = pd.read_csv(ext_path + "kieler_woche.csv")
df_kw["Start"] = pd.to_datetime(df_kw["Start"])
df_kw["Ende"] = pd.to_datetime(df_kw["Ende"])

kw_tage = set()
for _, row in df_kw.iterrows():
    kw_tage.update(pd.date_range(row["Start"], row["Ende"]))

df["KielerWoche"] = df["Datum"].isin(kw_tage).astype(int)
print(f"Kieler Woche: {df['KielerWoche'].sum() // 2} Tage erkannt (je WG)")

# --- 3. Niederschlag (monatlich) → numerisch ---
df_niederschlag = pd.read_csv(ext_path + "niederschlag.csv")
df_niederschlag[["_j", "_m"]] = df_niederschlag["category"].str.split("/", expand=True)
df_niederschlag["_j"] = df_niederschlag["_j"].astype(int)
df_niederschlag["_m"] = df_niederschlag["_m"].astype(int)
df_niederschlag["Niederschlag"] = df_niederschlag["Niederschlag"].replace(-999, np.nan).interpolate()

# Lookup-Dict: (Jahr, Monat) → Niederschlag
niederschlag_map = dict(zip(
    zip(df_niederschlag["_j"], df_niederschlag["_m"]),
    df_niederschlag["Niederschlag"]
))

df["Niederschlag"] = list(zip(df["Datum"].dt.year, df["Datum"].dt.month))
df["Niederschlag"] = df["Niederschlag"].map(niederschlag_map)

# --- 4. Sonnenscheindauer (monatlich) → numerisch ---
df_sonne = pd.read_csv(ext_path + "sonnenscheindauer.csv")
df_sonne[["_j", "_m"]] = df_sonne["category"].str.split("/", expand=True)
df_sonne["_j"] = df_sonne["_j"].astype(int)
df_sonne["_m"] = df_sonne["_m"].astype(int)
df_sonne["Sonnenschein"] = df_sonne["Sonnenschein"].replace(-999, np.nan).interpolate()

sonnenschein_map = dict(zip(
    zip(df_sonne["_j"], df_sonne["_m"]),
    df_sonne["Sonnenschein"]
))

df["Sonnenschein"] = list(zip(df["Datum"].dt.year, df["Datum"].dt.month))
df["Sonnenschein"] = df["Sonnenschein"].map(sonnenschein_map)

# --- 5. Temperatur (monatlich, Mittelwert) → numerisch ---
df_temp = pd.read_csv(ext_path + "temperatur.csv")
df_temp[["_j", "_m"]] = df_temp["category"].str.split("/", expand=True)
df_temp["_j"] = df_temp["_j"].astype(int)
df_temp["_m"] = df_temp["_m"].astype(int)
df_temp["Mittelwert"] = pd.to_numeric(df_temp["Mittelwert"], errors="coerce").interpolate()

temperatur_map = dict(zip(
    zip(df_temp["_j"], df_temp["_m"]),
    df_temp["Mittelwert"]
))

df["Temperatur"] = list(zip(df["Datum"].dt.year, df["Datum"].dt.month))
df["Temperatur"] = df["Temperatur"].map(temperatur_map)

# Überblick
print(f"\nNeue Spalten: Ferien, KielerWoche, Niederschlag, Sonnenschein, Temperatur")
print(f"Shape nach Anreicherung: {df.shape}")
print(f"Fehlende Werte in neuen Spalten:")
print(df[["Ferien", "KielerWoche", "Niederschlag", "Sonnenschein", "Temperatur"]].isnull().sum())
df[["Datum", "Warengruppe_text", "Ferien", "KielerWoche", "Niederschlag", "Sonnenschein", "Temperatur"]].sample(10, random_state=42)
# Out:
# Ferien: 473 Ferientage erkannt (je WG)
# Kieler Woche: 45 Tage erkannt (je WG)
#
# Neue Spalten: Ferien, KielerWoche, Niederschlag, Sonnenschein, Temperatur
# Shape nach Anreicherung: (3938, 20)
# Fehlende Werte in neuen Spalten:
# Ferien          0
# KielerWoche     0
# Niederschlag    0
# Sonnenschein    0
# Temperatur      0
# dtype: int64
#            Datum Warengruppe_text  Ferien  KielerWoche  Niederschlag  \
# 3767  2017-12-12         Brötchen       0            0          82.7
# 2639  2014-10-18         Brötchen       1            0          54.5
# 3789  2018-01-06         Brötchen       1            0          94.8
# 2664  2014-11-12         Brötchen       0            0          24.1
# 8726  2013-09-23           Kuchen       0            0          71.3
# 2540  2014-07-10         Brötchen       0            0          42.3
# 3081  2016-01-11         Brötchen       0            0          81.5
# 10372 2018-05-03           Kuchen       0            0          24.4
# 9667  2016-05-10           Kuchen       0            0          27.2
# 3396  2016-11-27         Brötchen       0            0          32.1
#
#        Sonnenschein  Temperatur
# 3767           24.6         4.2
# 2639           82.3        13.0
# 3789           31.5         3.4
# 2664           52.9         7.7
# 8726          132.0        13.7
# 2540          290.9        20.3
# 3081           27.8         1.1
# 10372         374.1        14.8
# 9667          261.2        13.6
# 3396           54.7         4.6

# %%
df.head()
# Out:
#           Datum  Warengruppe_num  Umsatz Warengruppe_text  Silvester  \
# 2174 2013-07-01                2  535.86         Brötchen          0
# 2175 2013-07-02                2  546.78         Brötchen          0
# 2176 2013-07-03                2  427.34         Brötchen          0
# 2177 2013-07-04                2  454.86         Brötchen          0
# 2178 2013-07-05                2  492.82         Brötchen          0
#
#       pre_Silvester  Wochentag_num   Wochentag  WT_Dienstag  WT_Donnerstag  \
# 2174              0              0      Montag            0              0
# 2175              0              1    Dienstag            1              0
# 2176              0              2    Mittwoch            0              0
# 2177              0              3  Donnerstag            0              1
# 2178              0              4     Freitag            0              0
#
#       WT_Freitag  WT_Mittwoch  WT_Montag  WT_Samstag  WT_Sonntag  Ferien  \
# 2174           0            0          1           0           0       1
# 2175           0            0          0           0           0       1
# 2176           0            1          0           0           0       1
# 2177           0            0          0           0           0       1
# 2178           1            0          0           0           0       1
#
#       KielerWoche  Niederschlag  Sonnenschein  Temperatur
# 2174            0          58.0         315.8        18.4
# 2175            0          58.0         315.8        18.4
# 2176            0          58.0         315.8        18.4
# 2177            0          58.0         315.8        18.4
# 2178            0          58.0         315.8        18.4

# %%
## Umsatz des gleichen Wochentags der Vorwoche (lag_1W)
# Da es sich um Tagesdaten handelt, entspricht „gleicher Wochentag der Vorwoche“ einem Lag von 7 Tagen,
# sofern dieser vorhanden ist. (Hinweis: Hier wird vereinfachend ignoriert, dass für einige Datümer keine Umsätze vorliegen.)
# Wichtig: Vorher zeitlich sortieren und nach Warengruppe trennen!

# Nach Warengruppe und Datum sortieren
df = df.sort_values(["Warengruppe_text", "Datum"])

# Lag-Feature: Umsatz der Vorwoche (gleicher Wochentag)
df["lag_1W"] = (
    df.groupby("Warengruppe_text")["Umsatz"]
      .shift(7)
)

# %%
# Ergebnis prüfen
df[[
    "Datum",
    "Warengruppe_text",
    "Umsatz",
    "lag_1W"
]].head(20)
# Out:
#           Datum Warengruppe_text  Umsatz  lag_1W
# 2174 2013-07-01         Brötchen  535.86     NaN
# 2175 2013-07-02         Brötchen  546.78     NaN
# 2176 2013-07-03         Brötchen  427.34     NaN
# 2177 2013-07-04         Brötchen  454.86     NaN
# 2178 2013-07-05         Brötchen  492.82     NaN
# 2179 2013-07-06         Brötchen  631.91     NaN
# 2180 2013-07-07         Brötchen  695.26     NaN
# 2181 2013-07-08         Brötchen  538.53  535.86
# 2182 2013-07-09         Brötchen  585.96  546.78
# 2183 2013-07-10         Brötchen  567.37  427.34
# 2184 2013-07-11         Brötchen  569.11  454.86
# 2185 2013-07-12         Brötchen  600.27  492.82
# 2186 2013-07-13         Brötchen  747.14  631.91
# 2187 2013-07-14         Brötchen  777.05  695.26
# 2188 2013-07-15         Brötchen  597.00  538.53
# 2189 2013-07-16         Brötchen  558.80  585.96
# 2190 2013-07-17         Brötchen  628.33  567.37
# 2191 2013-07-18         Brötchen  647.82  569.11
# 2192 2013-07-19         Brötchen  646.79  600.27
# 2193 2013-07-20         Brötchen  843.05  747.14

# %%
# Für die erste Woche des Datensatzes gibt es keine Vorwochenwerte!
df["lag_1W"].isnull().sum()
# Out:
# 14

# %%
# NaN Werte entfernen (Zeilen löschen)
df = df.dropna().copy()

# %%
df.head()
# Out:
#           Datum  Warengruppe_num  Umsatz Warengruppe_text  Silvester  \
# 2181 2013-07-08                2  538.53         Brötchen          0
# 2182 2013-07-09                2  585.96         Brötchen          0
# 2183 2013-07-10                2  567.37         Brötchen          0
# 2184 2013-07-11                2  569.11         Brötchen          0
# 2185 2013-07-12                2  600.27         Brötchen          0
#
#       pre_Silvester  Wochentag_num   Wochentag  WT_Dienstag  WT_Donnerstag  \
# 2181              0              0      Montag            0              0
# 2182              0              1    Dienstag            1              0
# 2183              0              2    Mittwoch            0              0
# 2184              0              3  Donnerstag            0              1
# 2185              0              4     Freitag            0              0
#
#       ...  WT_Mittwoch  WT_Montag  WT_Samstag  WT_Sonntag  Ferien  \
# 2181  ...            0          1           0           0       1
# 2182  ...            0          0           0           0       1
# 2183  ...            1          0           0           0       1
# 2184  ...            0          0           0           0       1
# 2185  ...            0          0           0           0       1
#
#       KielerWoche  Niederschlag  Sonnenschein  Temperatur  lag_1W
# 2181            0          58.0         315.8        18.4  535.86
# 2182            0          58.0         315.8        18.4  546.78
# 2183            0          58.0         315.8        18.4  427.34
# 2184            0          58.0         315.8        18.4  454.86
# 2185            0          58.0         315.8        18.4  492.82
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train/Test Split
#
# Jetzt wollen wir ```df``` trennen in ```df_train``` und ```df_test```, wobei die Daten für 2018 als Testdaten verwendet werden sollen.
#
# Zunächst behalten wir alle Attribute aus ```df```.

# %%
# Jahr aus dem Datum extrahieren
df["Jahr"] = df["Datum"].dt.year

# Trainingsdaten: alles vor 2018
df_train = df[df["Jahr"] < 2018].copy()

# Testdaten: genau das Jahr 2018
df_test = df[df["Jahr"] == 2018].copy()

print("Trainingsdaten:")
print("Zeitraum:", df_train["Datum"].min(), "bis", df_train["Datum"].max())
print("Anzahl Zeilen:", len(df_train))

print("\nTestdaten:")
print("Zeitraum:", df_test["Datum"].min(), "bis", df_test["Datum"].max())
print("Anzahl Zeilen:", len(df_test))
# Out:
# Trainingsdaten:
# Zeitraum: 2013-07-08 00:00:00 bis 2017-12-31 00:00:00
# Anzahl Zeilen: 3208
#
# Testdaten:
# Zeitraum: 2018-01-02 00:00:00 bis 2018-12-31 00:00:00
# Anzahl Zeilen: 716

# %% [markdown]
# ## 3. Modellauswahl
#
# Im folgenden werden zwei verschiedene Ansätze als Prognosemodelle betrachtet, die hier kurz diskutiert werden. Die Ergebnisse dienen als **Baseline** für den Hackathon.
#
# ### Modell 1: Heuristik „prognostizierter Umsatz = Umsatz der Vorwoche (lag_1W)“
#
# **Modellbeschreibung:** Die Prognose für einen Tag entspricht exakt dem Umsatz des gleichen Wochentages der Vorwoche.
#
# **Warum dieses Modell?**
#
# - Sehr einfache, intuitiv verständliche Baseline
# - Nutzt explizit Wochenmuster, die im Einzelhandel typisch sind
# - Kein Training notwendig
#
# **Stärken:**
#
# - Extrem einfach & transparent
# - Sehr robust bei stabilen Zeitreihen
# - Hervorragender Baseline-Vergleich
#
# **Schwächen:**
#
# - Reagiert nicht auf Sonderereignisse (z. B. Silvester)
# - Kein Lernen über längere Zeiträume
# - Kann systematische Fehler nicht korrigieren
#
# ### Modell 2: Lineare Regression
#
# **Modellbeschreibung:** Ein lineares Regressionsmodell mit folgenden Input-Features:
#
# - lag_1W
# - Dummy-Variablen für Wochentage
# - Dummy-Variable Silvester
#
# **Warum dieses Modell?**
#
# - Klassisches, gut erklärbares ML-Einstiegsmodell
# - Verbindet Zeitreihenidee (lag_1W) mit Kalenderfeatures
# - Sehr gut interpretierbar
#
# **Stärken:**
#
# - Lernt systematische Abweichungen vom Vorwochenwert
# - Modellparameter sind direkt interpretierbar
# - Schnell trainiert, stabil, gut für Demo-Zwecke
#
# **Schwächen:**
#
# - Annahme linearer Zusammenhänge
# - Keine Interaktionen oder Nichtlinearitäten
# - Begrenzte Modellkapazität bei komplexen Mustern

# %% [markdown]
# ## 4. Modellierung
#
# Sowohl für Modell 1 (Heuristik) als auch für Modell 2 (lineare Regression) verwenden wir die Daten in der vorliegenden Form. Ein weiteres Preprocessing ist hier nicht erforderlich.
#
# **Hinweis:** Allerdings trennen wir die Daten nach Warengruppen, weil wir in der explorativen Datenanalyse unterschiedliche Charakteristika je Warengruppe identifiziert hatten. Wir betrachten daher getrennte Prognosemodelle für Brötchen und Kuchen.
#
# Die **Zielvariable** ist der Umsatz, den wir prognostizieren wollen.

# %%
# Auswahl Input-Features (für lineare Regression)
feature_cols = [
    "Silvester",
    "WT_Dienstag",
    "WT_Donnerstag",
    "WT_Freitag",
    "WT_Mittwoch",
    "WT_Montag",
    "WT_Samstag",
    "WT_Sonntag",
    "lag_1W",
    # Externe Features
    "Ferien",
    "KielerWoche",
    "Niederschlag",
    "Sonnenschein",
    "Temperatur"
]

# Warengruppe 2 – Brötchen
df_train_WG2 = df_train[df_train["Warengruppe_num"] == 2]
df_test_WG2  = df_test[df_test["Warengruppe_num"] == 2]

X_train_WG2 = df_train_WG2[feature_cols]
y_train_WG2 = df_train_WG2["Umsatz"]

X_test_WG2 = df_test_WG2[feature_cols]
y_test_WG2 = df_test_WG2["Umsatz"]

# Heuristik
y_pred_heuristik_WG2 = df_test_WG2["lag_1W"]

# Lineare Regression
lin_reg_WG2 = LinearRegression()
lin_reg_WG2.fit(X_train_WG2, y_train_WG2)

y_pred_lr_WG2 = lin_reg_WG2.predict(X_test_WG2)

# Warengruppe 5 – Kuchen
df_train_WG5 = df_train[df_train["Warengruppe_num"] == 5]
df_test_WG5  = df_test[df_test["Warengruppe_num"] == 5]

X_train_WG5 = df_train_WG5[feature_cols]
y_train_WG5 = df_train_WG5["Umsatz"]

X_test_WG5 = df_test_WG5[feature_cols]
y_test_WG5 = df_test_WG5["Umsatz"]

# Heuristik
y_pred_heuristik_WG5 = df_test_WG5["lag_1W"]

# Lineare Regression
lin_reg_WG5 = LinearRegression()
lin_reg_WG5.fit(X_train_WG5, y_train_WG5)

y_pred_lr_WG5 = lin_reg_WG5.predict(X_test_WG5)

# %% [markdown]
# ## 5. Evaluation und Diskussion der Ergebnisse
#
# ### Metriken
#
# Nachdem wir unsere Baseline-Modelle trainiert haben bzw. die Modellvorhersagen erhalten haben, wollen wir die Prognosegüte bewerten. In der explorativen Datenanalyse hatten wir gesehen, dass es für die Warengruppe 5 (Kuchen) einzelne Tage mit extrem hohen Umsätzen gibt (Silvester). Für diese Tage ist eine gute Prognose daher besonders wichtig.
#
# Für die Warengruppe 2 (Brötchen) habe haben wir in der explorativen Datenanalyse gesehen, dass es zwar keine extremen Ausreißer gibt, aber dafür stärkere saisonale Schwankungen im Jahresverlauf.
#
# Als Metrik verwenden wir daher vorrangig den **root mean squared error** (RMSE).
#
# **Definition:** Quadratischer Fehler, gemittelt und anschließend die Wurzel daraus
#
# $$
# \mathrm{RMSE} = \sqrt{ \frac{1}{n} \sum_{i=1}^{n} \left( y_i - \hat{y}_i \right)^2 }
# $$
#
# **Interpretation:**
#
# - Einheit ist dieselbe wie der Umsatz (Euro)
# - Große Fehler wirken überproportional stark
# - Hebt extreme Fehlprognosen hervor
# - Sehr verbreitet in Prognose- und Zeitreihenproblemen
# - Gut geeignet, wenn Ausreißer besonders schmerzhaft sind
#
# **Nachteile:**
#
# - Stärker verzerrt durch einzelne extreme Tage
# - Weniger intuitiv als MAE
#
# **Wichtig:** Für das Ranking der Modelle in der Rangliste ist der RMSE entscheidend!
#
# Daneben betrachten wir den **mean absolute error** (MAE).
#
# **Definition:** Der durchschnittliche absolute Fehler zwischen Prognose und tatsächlichem Wert
#
# $$
# \mathrm{MAE} = \frac{1}{n} \sum_{i=1}^{n} \left| y_i - \hat{y}_i \right|
# $$
#
# **Interpretation:**
#
# - Einheit ist dieselbe wie der Umsatz (Euro)
# - Gibt an: „Wie viele Euro liegen wir im Schnitt daneben?“
# - Sehr robust gegenüber Ausreißern
# - Leicht verständlich
# - Passt manchmal gut zu geschäftlichen Fragestellungen
#
# **Nachteile:**
#
# - Große Fehler werden nicht stärker bestraft als kleine Abweichungen
#
# **Wichtig:** Den MAE betrachten wir als Begleitmetrik. Der Wert ist für das Ranking der Modelle aber nicht entscheidend.

# %%
# Berechne mean absolute error (mae)
mae_heuristik_WG2 = mean_absolute_error(y_test_WG2, y_pred_heuristik_WG2)
mae_lr_WG2 = mean_absolute_error(y_test_WG2, y_pred_lr_WG2)
mae_heuristik_WG5 = mean_absolute_error(y_test_WG5, y_pred_heuristik_WG5)
mae_lr_WG5 = mean_absolute_error(y_test_WG5, y_pred_lr_WG5)

# Berechne root mean squarred error (rmse)
rmse_heuristik_WG2 = np.sqrt(mean_squared_error(y_test_WG2, y_pred_heuristik_WG2))
rmse_lr_WG2 = np.sqrt(mean_squared_error(y_test_WG2, y_pred_lr_WG2))
rmse_heuristik_WG5 = np.sqrt(mean_squared_error(y_test_WG5, y_pred_heuristik_WG5))
rmse_lr_WG5 = np.sqrt(mean_squared_error(y_test_WG5, y_pred_lr_WG5))

# Ergebnisse ausgeben
print("Warengruppe 2 – Brötchen")
print("Heuristik (lag_1W):")
print(f"  MAE : {mae_heuristik_WG2:.2f}")
print(f"  RMSE: {rmse_heuristik_WG2:.2f}")
print("Lineare Regression:")
print(f"  MAE : {mae_lr_WG2:.2f}")
print(f"  RMSE: {rmse_lr_WG2:.2f}")
print()

print("Warengruppe 5 – Kuchen")
print("Heuristik (lag_1W):")
print(f"  MAE : {mae_heuristik_WG5:.2f}")
print(f"  RMSE: {rmse_heuristik_WG5:.2f}")
print("Lineare Regression:")
print(f"  MAE : {mae_lr_WG5:.2f}")
print(f"  RMSE: {rmse_lr_WG5:.2f}")
# Out:
# Warengruppe 2 – Brötchen
# Heuristik (lag_1W):
#   MAE : 55.74
#   RMSE: 81.76
# Lineare Regression:
#   MAE : 45.10
#   RMSE: 60.77
#
# Warengruppe 5 – Kuchen
# Heuristik (lag_1W):
#   MAE : 55.60
#   RMSE: 117.16
# Lineare Regression:
#   MAE : 39.44
#   RMSE: 53.10

# %% [markdown]
# ### Diskussion
#
# Interpretation der Ergebnisse für **Warengruppe 2 (Brötchen)**
#
# - Die Heuristik ist beim durchschnittlichen Fehler (MAE) minimal besser im Vergleich zur linearen Regression.
# - Die lineare Regression reduziert aber die Extremfehler deutlich, was sich in einem niedrigeren RMSE widerspiegelt.
# - Die Regression lernt also, große Abweichungen zu dämpfen.
# - Für Brötchen ist das Wochenmuster bereits sehr stabil. Zusätzliche Features (Silvester, Wochentage) bringen nur begrenzten Mehrwert.
#
# Interpretation der Ergebnisse für **Warengruppe 5 (Kuchen)**
#
# - Die lineare Regression ist klar überlegen bei MAE und RMSE.
# - Besonders auffällig: RMSE halbiert sich
# - Die Regression erklärt Sondertage und Ausreißer deutlich besser.
# - Kuchenumsätze sind volatiler und profitieren stark von Kalender-Features (vor allem: Silvester).
#
# ### Analyse der Residuen
#
# **Definition:** Das Residuum ist die Abweichung zwischen tatsächlichem und prognostiziertem Umsatz:
#
# $$
# \text{Residuum} = y - \hat{y}
# $$
#
# **Interpretation:**
#
# - positiv → Modell unterschätzt den Umsatz
# - negativ → Modell überschätzt den Umsatz
#
# - Erkennen systematischer Fehler (z. B. immer montags daneben)
# - Prüfen, ob Fehler zufällig oder strukturiert sind
#
# **Grundlage für:**
#
# - Diagnose von Ausreißern
# - Modellverbesserung
# - Feature Engineering

# %%
# Warengruppe 2 – Brötchen
df_test_WG2 = df_test[df_test["Warengruppe_num"] == 2].copy()

df_test_WG2["resid_heuristik"] = (
    df_test_WG2["Umsatz"] - df_test_WG2["lag_1W"]
)

df_test_WG2["resid_lr"] = (
    df_test_WG2["Umsatz"] - y_pred_lr_WG2
)

# Residuen über die Zeit
plt.figure(figsize=(12, 4))
plt.plot(df_test_WG2["Datum"], df_test_WG2["resid_heuristik"], label="Heuristik", alpha=0.7)
plt.plot(df_test_WG2["Datum"], df_test_WG2["resid_lr"], label="Lineare Regression", alpha=0.7)
plt.axhline(0, linestyle="--")
plt.title("Residuen über die Zeit – Brötchen (WG 2)")
plt.xlabel("Datum")
plt.ylabel("Residuum")
plt.legend()
plt.tight_layout()
plt.show()

# Residuenverteilung
plt.figure(figsize=(10, 4))
plt.hist(df_test_WG2["resid_heuristik"], bins=40, alpha=0.5, label="Heuristik")
plt.hist(df_test_WG2["resid_lr"], bins=40, alpha=0.5, label="Lineare Regression")
plt.axvline(0, linestyle="--")
plt.title("Residuenverteilung – Brötchen (WG 2)")
plt.xlabel("Residuum")
plt.ylabel("Häufigkeit")
plt.legend()
plt.tight_layout()
plt.show()

# Warengruppe 5 – Kuchen
df_test_WG5 = df_test[df_test["Warengruppe_num"] == 5].copy()

df_test_WG5["resid_heuristik"] = (
    df_test_WG5["Umsatz"] - df_test_WG5["lag_1W"]
)

df_test_WG5["resid_lr"] = (
    df_test_WG5["Umsatz"] - y_pred_lr_WG5
)

# Residuen über die Zeit
plt.figure(figsize=(12, 4))
plt.plot(df_test_WG5["Datum"], df_test_WG5["resid_heuristik"], label="Heuristik", alpha=0.7)
plt.plot(df_test_WG5["Datum"], df_test_WG5["resid_lr"], label="Lineare Regression", alpha=0.7)
plt.axhline(0, linestyle="--")
plt.title("Residuen über die Zeit – Kuchen (WG 5)")
plt.xlabel("Datum")
plt.ylabel("Residuum")
plt.legend()
plt.tight_layout()
plt.show()

# Residuenverteilung
plt.figure(figsize=(10, 4))
plt.hist(df_test_WG5["resid_heuristik"], bins=40, alpha=0.5, label="Heuristik")
plt.hist(df_test_WG5["resid_lr"], bins=40, alpha=0.5, label="Lineare Regression")
plt.axvline(0, linestyle="--")
plt.title("Residuenverteilung – Kuchen (WG 5)")
plt.xlabel("Residuum")
plt.ylabel("Häufigkeit")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Diskussion der Residuen
#
# Für die **Warengruppe 2 (Brötchen)** fällt im Zeitverlauf der Residuen auf, dass es längere Phasen mit größeren Abweichungen gibt, und zwar für beide betrachteten Prognose-Modelle. Die Verteilung der Residuen ist ähnlich breit, wobei die lineare Regression offenbar den Umsatz systematisch zu hoch vorhersagt.
#
# Für die **Warengruppe 5 (Kuchen)** zeigen sich die Residuen im Zeitverlauf zum Großteil wie ein zufälliges Rauschen um die Nulllinie. Lediglich für die Heuristik gibt es zwei extreme Werte, eine positive und eine negative Abweichung von tatsächlichem und prognostiziertem Umsatz. Das stark positive Residum am letzten Tag des Jahres ist auf den unterschätzten Umsatz für Silvester zurückzuführen. Die starken Abweichungen der Heuristik verzerren die Darstellung der Residuenverteilung. Hier lohnt es sich, tiefer einzusteigen und die Modelle zu erweitern, um die Prognosegüte zu erhöhen.

# %% [markdown]
# ## 6. Reflexion und Ausblick
#
# Im Rahmen der Analyse traten mehrere typische Herausforderungen der Zeitreihen- und Umsatzprognose auf. Eine zentrale Schwierigkeit bestand in der starken **Heterogenität der Warengruppen**. Während die Umsätze für Brötchen relativ stabilen Wochenmustern folgen, zeigen die Kuchenumsätze eine deutlich höhere Volatilität sowie ausgeprägte Ausreißer an einzelnen Tagen. Diese Unterschiede machten es notwendig, separate Modelle je Warengruppe zu betrachten, da ein gemeinsames Modell die jeweiligen Charakteristika nicht adäquat abbilden konnte.
#
# Eine weitere Herausforderung ergab sich aus der Modellierung von **Sonderereignissen**. Die einfache Heuristik auf Basis des Vorwochenumsatzes versagte insbesondere an Tagen mit atypischem Nachfrageverhalten, wie etwa an Silvester. Durch die Einführung zusätzlicher Kalender-Features (z. B. Dummy-Variable für Silvester) konnte dieses Problem teilweise adressiert werden, was sich insbesondere bei der Warengruppe Kuchen in einer deutlichen Verbesserung der Prognosegüte widerspiegelte.
#
# Trotz dieser Erweiterungen bleiben die betrachteten Modelle vergleichsweise einfach. Die lineare Regression ist zwar gut interpretierbar und reduziert extreme Prognosefehler, sie ist jedoch auf lineare Zusammenhänge beschränkt und kann komplexe Interaktionen zwischen Features nur eingeschränkt abbilden.
#
# Zur weiteren Verbesserung der Prognosegüte bieten sich mehrere Ansätze an. Auf der Feature-Ebene könnten zusätzliche zeitliche Merkmale wie Monat, Kalenderwoche, Feiertage oder Brückentage integriert werden. Auch die Verwendung mehrerer Lag-Variablen (z. B. Umsatz der letzten zwei oder drei Wochen) könnte helfen, längerfristige Trends besser zu erfassen.
#
# Auf Modell-Ebene stellen nichtlineare Verfahren eine naheliegende Erweiterung dar. Entscheidungsbaum-basierte Modelle wie Random Forests können Interaktionen automatisch lernen und sind robuster gegenüber Ausreißern. Darüber hinaus eignen sich neuronale Netze – insbesondere rekurrente Architekturen wie LSTM – zur expliziten Modellierung zeitlicher Abhängigkeiten, erfordern jedoch eine sorgfältige Feature-Skalierung und Modellvalidierung.
#
# Zusammenfassend zeigt die Analyse, dass bereits einfache **Baseline**-Modelle wertvolle Erkenntnisse liefern können, zugleich aber auch deutlich machen, wo ihre Grenzen liegen.
#
# ## Feuer frei für den Hackathon!!!
#
# Genau an dieser Stelle setzt die Data Challenge an: Jetzt seid Ihr aufgefordert, durch Anreicherung der Daten, gezieltes Feature Engineering und den Einsatz geeigneter Modelle die Prognosegüte systematisch zu verbessern.
# Auf Euch wartet... **Ruhm und Ehre!** :-)

# %% [markdown]
# ## Modell 3: LSTM – Lean Edition
#
# **Erkenntnis aus v2:** Mehr Features ≠ bessere Performance. 28 Features × 21 Zeitschritte × Bidirectional = **348k Parameter** bei nur ~1.600 Trainingssequenzen → klassisches Overfitting.
#
# **Neuer Ansatz: „Less is more"**
#
# - **Nur 5 Features** statt 28: Umsatz + Silvester + Wochentag (numerisch) + Ferien + ist_geschlossen
# - **Einfaches LSTM** mit 1 Schicht, 32 Units → nur ~5k Parameter
# - **LOOKBACK = 7** (1 Woche) — das natürliche Wochenmuster reicht
# - **MinMaxScaler** — bei wenigen Features funktioniert er gut
# - Das LSTM soll die **zeitliche Dynamik des Umsatzes** selbst lernen, nicht aus einer Feature-Flut raten

# %%
# ============================================================
# LSTM Lean – Imports & Setup
# ============================================================
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler

tf.random.set_seed(42)
np.random.seed(42)

# Hyperparameter – bewusst schlank
LOOKBACK = 7        # 1 Woche – das natürliche Muster
EPOCHS = 150
BATCH_SIZE = 32
LSTM_UNITS = 32     # Wenig Kapazität → zwingt zur Generalisierung

print(f"TensorFlow Version: {tf.__version__}")
print(f"Lookback: {LOOKBACK}, Epochs: {EPOCHS}, Batch: {BATCH_SIZE}, Units: {LSTM_UNITS}")

# Minimale Feature-Auswahl: nur was wirklich zählt
lstm_features_lean = [
    "Umsatz",           # Umsatz-Zeitreihe selbst (Kerninfo)
    "Silvester",        # Stärkster Einzeleffekt (vor allem Kuchen)
    "WT_Dienstag",
    "WT_Donnerstag",
    "WT_Freitag",
    "WT_Mittwoch",
    "WT_Montag",
    "WT_Samstag",
    "WT_Sonntag",
    "KielerWoche",      # Viele Touristen
    "pre_Silvester"
]

print(f"Features: {lstm_features_lean}")
print(f"Anzahl: {len(lstm_features_lean)} (davon Umsatz als Target + Sequenz-Input)")

def create_sequences(X, y, lookback):
    """Erstellt Sequenzen der Länge `lookback`."""
    X_seq, y_seq = [], []
    for i in range(lookback, len(X)):
        X_seq.append(X[i - lookback : i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)
# Out:
# TensorFlow Version: 2.18.1
# Lookback: 7, Epochs: 150, Batch: 32, Units: 32
# Features: ['Umsatz', 'Silvester', 'WT_Dienstag', 'WT_Donnerstag', 'WT_Freitag', 'WT_Mittwoch', 'WT_Montag', 'WT_Samstag', 'WT_Sonntag', 'KielerWoche', 'pre_Silvester']
# Anzahl: 11 (davon Umsatz als Target + Sequenz-Input)

# %%
# ============================================================
# LSTM Lean – Datenaufbereitung
# ============================================================

# --- Warengruppe 2 – Brötchen ---
train_wg2 = df_train[df_train["Warengruppe_num"] == 2].sort_values("Datum").reset_index(drop=True)
test_wg2  = df_test[df_test["Warengruppe_num"] == 2].sort_values("Datum").reset_index(drop=True)

scaler_wg2 = MinMaxScaler()
train_wg2_scaled = scaler_wg2.fit_transform(train_wg2[lstm_features_lean])
test_wg2_scaled  = scaler_wg2.transform(test_wg2[lstm_features_lean])

# Umsatz ist Spalte 0 → separater Scaler für Rücktransformation
scaler_y_wg2 = MinMaxScaler()
scaler_y_wg2.fit(train_wg2[["Umsatz"]])

# Target = Spalte 0 (Umsatz)
X_train_lstm_wg2, y_train_lstm_wg2 = create_sequences(
    train_wg2_scaled, train_wg2_scaled[:, 0], LOOKBACK
)

combined_wg2_scaled = np.vstack([train_wg2_scaled, test_wg2_scaled])
X_test_lstm_wg2, y_test_lstm_wg2 = create_sequences(
    combined_wg2_scaled[len(train_wg2_scaled) - LOOKBACK:],
    combined_wg2_scaled[len(train_wg2_scaled) - LOOKBACK:, 0],
    LOOKBACK
)

# --- Warengruppe 5 – Kuchen ---
train_wg5 = df_train[df_train["Warengruppe_num"] == 5].sort_values("Datum").reset_index(drop=True)
test_wg5  = df_test[df_test["Warengruppe_num"] == 5].sort_values("Datum").reset_index(drop=True)

scaler_wg5 = MinMaxScaler()
train_wg5_scaled = scaler_wg5.fit_transform(train_wg5[lstm_features_lean])
test_wg5_scaled  = scaler_wg5.transform(test_wg5[lstm_features_lean])

scaler_y_wg5 = MinMaxScaler()
scaler_y_wg5.fit(train_wg5[["Umsatz"]])

X_train_lstm_wg5, y_train_lstm_wg5 = create_sequences(
    train_wg5_scaled, train_wg5_scaled[:, 0], LOOKBACK
)

combined_wg5_scaled = np.vstack([train_wg5_scaled, test_wg5_scaled])
X_test_lstm_wg5, y_test_lstm_wg5 = create_sequences(
    combined_wg5_scaled[len(train_wg5_scaled) - LOOKBACK:],
    combined_wg5_scaled[len(train_wg5_scaled) - LOOKBACK:, 0],
    LOOKBACK
)

print("=== LSTM Lean – Sequenzen ===")
print(f"Features pro Zeitschritt: {X_train_lstm_wg2.shape[2]}")
print(f"Parameter pro Sequenz: {LOOKBACK} × {X_train_lstm_wg2.shape[2]} = {LOOKBACK * X_train_lstm_wg2.shape[2]}")
print(f"\nBrötchen: Train {X_train_lstm_wg2.shape[0]} / Test {X_test_lstm_wg2.shape[0]} Sequenzen")
print(f"Kuchen:   Train {X_train_lstm_wg5.shape[0]} / Test {X_test_lstm_wg5.shape[0]} Sequenzen")
# Out:
# === LSTM Lean – Sequenzen ===
# Features pro Zeitschritt: 11
# Parameter pro Sequenz: 7 × 11 = 77
#
# Brötchen: Train 1597 / Test 358 Sequenzen
# Kuchen:   Train 1597 / Test 358 Sequenzen

# %%
# ============================================================
# LSTM Lean – Einfache Architektur + Training
# ============================================================

def build_lstm_refined(input_shape, units=32):
    model = Sequential([
        # Layer 1: Captures low-level patterns
        LSTM(units, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        # Layer 2: Captures higher-level temporal dependencies
        LSTM(units // 2), 
        Dropout(0.2),
        Dense(16, activation="relu"),
        Dense(1)
    ])
    # Use a specific learning rate instead of default "adam"
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=opt, loss="huber", metrics=["mae"])
    return model

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True,
    verbose=1
)

# --- Brötchen (WG2) ---
print("=" * 50)
print("Training LSTM Lean – Brötchen (WG2)")
print("=" * 50)

lstm_wg2 = build_lstm_refined(
    input_shape=(X_train_lstm_wg2.shape[1], X_train_lstm_wg2.shape[2])
)
lstm_wg2.summary()

history_wg2 = lstm_wg2.fit(
    X_train_lstm_wg2, y_train_lstm_wg2,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.15,
    callbacks=[early_stop],
    verbose=1
)

# --- Kuchen (WG5) ---
print("\n" + "=" * 50)
print("Training LSTM Lean – Kuchen (WG5)")
print("=" * 50)

lstm_wg5 = build_lstm_refined(
    input_shape=(X_train_lstm_wg5.shape[1], X_train_lstm_wg5.shape[2])
)

history_wg5 = lstm_wg5.fit(
    X_train_lstm_wg5, y_train_lstm_wg5,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.15,
    callbacks=[early_stop],
    verbose=1
)

total_params = lstm_wg2.count_params()
print(f"\nParameter pro Modell: {total_params:,} (vs. 348k in v2 → {348865/total_params:.0f}x weniger!)")
# Out:
# ==================================================
# Training LSTM Lean – Brötchen (WG2)
# ==================================================
# /Users/jano/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 7, 32)          │         5,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 7, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 16)             │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,057 (35.38 KB)
#  Trainable params: 9,057 (35.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0439 - mae: 0.2362 - val_loss: 0.0079 - val_mae: 0.1034
# Epoch 2/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0439 - mae: 0.2362 - val_loss: 0.0079 - val_mae: 0.1034
# Epoch 2/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0128 - mae: 0.1266 - val_loss: 0.0046 - val_mae: 0.0747
# Epoch 3/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0128 - mae: 0.1266 - val_loss: 0.0046 - val_mae: 0.0747
# Epoch 3/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0073 - mae: 0.0912 - val_loss: 0.0041 - val_mae: 0.0687
# Epoch 4/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0073 - mae: 0.0912 - val_loss: 0.0041 - val_mae: 0.0687
# Epoch 4/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0063 - mae: 0.0836 - val_loss: 0.0037 - val_mae: 0.0664
# Epoch 5/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0063 - mae: 0.0836 - val_loss: 0.0037 - val_mae: 0.0664
# Epoch 5/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0060 - mae: 0.0797 - val_loss: 0.0038 - val_mae: 0.0644
# Epoch 6/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0060 - mae: 0.0797 - val_loss: 0.0038 - val_mae: 0.0644
# Epoch 6/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0057 - mae: 0.0762 - val_loss: 0.0037 - val_mae: 0.0636
# Epoch 7/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0057 - mae: 0.0762 - val_loss: 0.0037 - val_mae: 0.0636
# Epoch 7/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0055 - mae: 0.0757 - val_loss: 0.0035 - val_mae: 0.0623
# Epoch 8/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0055 - mae: 0.0757 - val_loss: 0.0035 - val_mae: 0.0623
# Epoch 8/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0052 - mae: 0.0734 - val_loss: 0.0034 - val_mae: 0.0617
# Epoch 9/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0052 - mae: 0.0734 - val_loss: 0.0034 - val_mae: 0.0617
# Epoch 9/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0051 - mae: 0.0725 - val_loss: 0.0034 - val_mae: 0.0602
# Epoch 10/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0051 - mae: 0.0725 - val_loss: 0.0034 - val_mae: 0.0602
# Epoch 10/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0053 - mae: 0.0735 - val_loss: 0.0034 - val_mae: 0.0601
# Epoch 11/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0053 - mae: 0.0735 - val_loss: 0.0034 - val_mae: 0.0601
# Epoch 11/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0047 - mae: 0.0683 - val_loss: 0.0033 - val_mae: 0.0603
# Epoch 12/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0047 - mae: 0.0683 - val_loss: 0.0033 - val_mae: 0.0603
# Epoch 12/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0048 - mae: 0.0693 - val_loss: 0.0033 - val_mae: 0.0603
# Epoch 13/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0048 - mae: 0.0693 - val_loss: 0.0033 - val_mae: 0.0603
# Epoch 13/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0047 - mae: 0.0692 - val_loss: 0.0034 - val_mae: 0.0628
# Epoch 14/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0047 - mae: 0.0692 - val_loss: 0.0034 - val_mae: 0.0628
# Epoch 14/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - mae: 0.0689 - val_loss: 0.0032 - val_mae: 0.0591
# Epoch 15/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - mae: 0.0689 - val_loss: 0.0032 - val_mae: 0.0591
# Epoch 15/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0043 - mae: 0.0670 - val_loss: 0.0032 - val_mae: 0.0597
# Epoch 16/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0043 - mae: 0.0670 - val_loss: 0.0032 - val_mae: 0.0597
# Epoch 16/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0043 - mae: 0.0660 - val_loss: 0.0032 - val_mae: 0.0592
# Epoch 17/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0043 - mae: 0.0660 - val_loss: 0.0032 - val_mae: 0.0592
# Epoch 17/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0042 - mae: 0.0666 - val_loss: 0.0032 - val_mae: 0.0585
# Epoch 18/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0042 - mae: 0.0666 - val_loss: 0.0032 - val_mae: 0.0585
# Epoch 18/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0043 - mae: 0.0644 - val_loss: 0.0031 - val_mae: 0.0586
# Epoch 19/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0043 - mae: 0.0644 - val_loss: 0.0031 - val_mae: 0.0586
# Epoch 19/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0044 - mae: 0.0662 - val_loss: 0.0031 - val_mae: 0.0593
# Epoch 20/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0044 - mae: 0.0662 - val_loss: 0.0031 - val_mae: 0.0593
# Epoch 20/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0043 - mae: 0.0665 - val_loss: 0.0031 - val_mae: 0.0581
# Epoch 21/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0043 - mae: 0.0665 - val_loss: 0.0031 - val_mae: 0.0581
# Epoch 21/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0044 - mae: 0.0655 - val_loss: 0.0030 - val_mae: 0.0580
# Epoch 22/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0044 - mae: 0.0655 - val_loss: 0.0030 - val_mae: 0.0580
# Epoch 22/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0041 - mae: 0.0651 - val_loss: 0.0031 - val_mae: 0.0576
# Epoch 23/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0041 - mae: 0.0651 - val_loss: 0.0031 - val_mae: 0.0576
# Epoch 23/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0040 - mae: 0.0627 - val_loss: 0.0031 - val_mae: 0.0589
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0040 - mae: 0.0627 - val_loss: 0.0031 - val_mae: 0.0589
# Epoch 24/150
# Epoch 24/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0041 - mae: 0.0644 - val_loss: 0.0029 - val_mae: 0.0567
# Epoch 25/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0041 - mae: 0.0644 - val_loss: 0.0029 - val_mae: 0.0567
# Epoch 25/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0040 - mae: 0.0636 - val_loss: 0.0028 - val_mae: 0.0564
# Epoch 26/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0040 - mae: 0.0636 - val_loss: 0.0028 - val_mae: 0.0564
# Epoch 26/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0039 - mae: 0.0633 - val_loss: 0.0030 - val_mae: 0.0588
# Epoch 27/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0039 - mae: 0.0633 - val_loss: 0.0030 - val_mae: 0.0588
# Epoch 27/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0038 - mae: 0.0625 - val_loss: 0.0030 - val_mae: 0.0588
# Epoch 28/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0038 - mae: 0.0625 - val_loss: 0.0030 - val_mae: 0.0588
# Epoch 28/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0040 - mae: 0.0636 - val_loss: 0.0029 - val_mae: 0.0569
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0040 - mae: 0.0636 - val_loss: 0.0029 - val_mae: 0.0569
# Epoch 29/150
# Epoch 29/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0036 - mae: 0.0606 - val_loss: 0.0029 - val_mae: 0.0567
# Epoch 30/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0036 - mae: 0.0606 - val_loss: 0.0029 - val_mae: 0.0567
# Epoch 30/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0036 - mae: 0.0609 - val_loss: 0.0027 - val_mae: 0.0548
# Epoch 31/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0036 - mae: 0.0609 - val_loss: 0.0027 - val_mae: 0.0548
# Epoch 31/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035 - mae: 0.0594 - val_loss: 0.0027 - val_mae: 0.0548
# Epoch 32/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035 - mae: 0.0594 - val_loss: 0.0027 - val_mae: 0.0548
# Epoch 32/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035 - mae: 0.0596 - val_loss: 0.0029 - val_mae: 0.0591
# Epoch 33/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035 - mae: 0.0596 - val_loss: 0.0029 - val_mae: 0.0591
# Epoch 33/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0037 - mae: 0.0615 - val_loss: 0.0027 - val_mae: 0.0548
# Epoch 34/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0037 - mae: 0.0615 - val_loss: 0.0027 - val_mae: 0.0548
# Epoch 34/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0036 - mae: 0.0601 - val_loss: 0.0027 - val_mae: 0.0547
# Epoch 35/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0036 - mae: 0.0601 - val_loss: 0.0027 - val_mae: 0.0547
# Epoch 35/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0034 - mae: 0.0583 - val_loss: 0.0028 - val_mae: 0.0576
# Epoch 36/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0034 - mae: 0.0583 - val_loss: 0.0028 - val_mae: 0.0576
# Epoch 36/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0034 - mae: 0.0590 - val_loss: 0.0027 - val_mae: 0.0551
# Epoch 37/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0034 - mae: 0.0590 - val_loss: 0.0027 - val_mae: 0.0551
# Epoch 37/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0036 - mae: 0.0597 - val_loss: 0.0027 - val_mae: 0.0542
# Epoch 38/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0036 - mae: 0.0597 - val_loss: 0.0027 - val_mae: 0.0542
# Epoch 38/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0034 - mae: 0.0592 - val_loss: 0.0026 - val_mae: 0.0544
# Epoch 39/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0034 - mae: 0.0592 - val_loss: 0.0026 - val_mae: 0.0544
# Epoch 39/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0033 - mae: 0.0575 - val_loss: 0.0026 - val_mae: 0.0544
# Epoch 40/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0033 - mae: 0.0575 - val_loss: 0.0026 - val_mae: 0.0544
# Epoch 40/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034 - mae: 0.0598 - val_loss: 0.0027 - val_mae: 0.0554
# Epoch 41/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034 - mae: 0.0598 - val_loss: 0.0027 - val_mae: 0.0554
# Epoch 41/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0035 - mae: 0.0592 - val_loss: 0.0026 - val_mae: 0.0534
# Epoch 42/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0035 - mae: 0.0592 - val_loss: 0.0026 - val_mae: 0.0534
# Epoch 42/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0034 - mae: 0.0593 - val_loss: 0.0026 - val_mae: 0.0537
# Epoch 43/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0034 - mae: 0.0593 - val_loss: 0.0026 - val_mae: 0.0537
# Epoch 43/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0034 - mae: 0.0594 - val_loss: 0.0026 - val_mae: 0.0541
# Epoch 44/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0034 - mae: 0.0594 - val_loss: 0.0026 - val_mae: 0.0541
# Epoch 44/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034 - mae: 0.0595 - val_loss: 0.0027 - val_mae: 0.0546
# Epoch 45/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034 - mae: 0.0595 - val_loss: 0.0027 - val_mae: 0.0546
# Epoch 45/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0564 - val_loss: 0.0026 - val_mae: 0.0535
# Epoch 46/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0564 - val_loss: 0.0026 - val_mae: 0.0535
# Epoch 46/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0577 - val_loss: 0.0026 - val_mae: 0.0541
# Epoch 47/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0577 - val_loss: 0.0026 - val_mae: 0.0541
# Epoch 47/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - mae: 0.0562 - val_loss: 0.0026 - val_mae: 0.0539
# Epoch 48/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - mae: 0.0562 - val_loss: 0.0026 - val_mae: 0.0539
# Epoch 48/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mae: 0.0548 - val_loss: 0.0030 - val_mae: 0.0599
# Epoch 49/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mae: 0.0548 - val_loss: 0.0030 - val_mae: 0.0599
# Epoch 49/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0032 - mae: 0.0575 - val_loss: 0.0025 - val_mae: 0.0536
# Epoch 50/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0032 - mae: 0.0575 - val_loss: 0.0025 - val_mae: 0.0536
# Epoch 50/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - mae: 0.0557 - val_loss: 0.0026 - val_mae: 0.0540
# Epoch 51/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - mae: 0.0557 - val_loss: 0.0026 - val_mae: 0.0540
# Epoch 51/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0032 - mae: 0.0578 - val_loss: 0.0024 - val_mae: 0.0512
# Epoch 52/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0032 - mae: 0.0578 - val_loss: 0.0024 - val_mae: 0.0512
# Epoch 52/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - mae: 0.0561 - val_loss: 0.0025 - val_mae: 0.0528
# Epoch 53/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - mae: 0.0561 - val_loss: 0.0025 - val_mae: 0.0528
# Epoch 53/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0032 - mae: 0.0578 - val_loss: 0.0025 - val_mae: 0.0524
# Epoch 54/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0032 - mae: 0.0578 - val_loss: 0.0025 - val_mae: 0.0524
# Epoch 54/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0031 - mae: 0.0551 - val_loss: 0.0025 - val_mae: 0.0540
# Epoch 55/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0031 - mae: 0.0551 - val_loss: 0.0025 - val_mae: 0.0540
# Epoch 55/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0032 - mae: 0.0585 - val_loss: 0.0026 - val_mae: 0.0537
# Epoch 56/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0032 - mae: 0.0585 - val_loss: 0.0026 - val_mae: 0.0537
# Epoch 56/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0570 - val_loss: 0.0025 - val_mae: 0.0520
# Epoch 57/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0570 - val_loss: 0.0025 - val_mae: 0.0520
# Epoch 57/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - mae: 0.0560 - val_loss: 0.0025 - val_mae: 0.0526
# Epoch 58/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - mae: 0.0560 - val_loss: 0.0025 - val_mae: 0.0526
# Epoch 58/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mae: 0.0567 - val_loss: 0.0024 - val_mae: 0.0509
# Epoch 59/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mae: 0.0567 - val_loss: 0.0024 - val_mae: 0.0509
# Epoch 59/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - mae: 0.0558 - val_loss: 0.0024 - val_mae: 0.0504
# Epoch 60/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - mae: 0.0558 - val_loss: 0.0024 - val_mae: 0.0504
# Epoch 60/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0031 - mae: 0.0565 - val_loss: 0.0024 - val_mae: 0.0514
# Epoch 61/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0031 - mae: 0.0565 - val_loss: 0.0024 - val_mae: 0.0514
# Epoch 61/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0029 - mae: 0.0549 - val_loss: 0.0024 - val_mae: 0.0518
# Epoch 62/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0029 - mae: 0.0549 - val_loss: 0.0024 - val_mae: 0.0518
# Epoch 62/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0028 - mae: 0.0542 - val_loss: 0.0023 - val_mae: 0.0502
# Epoch 63/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0028 - mae: 0.0542 - val_loss: 0.0023 - val_mae: 0.0502
# Epoch 63/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0030 - mae: 0.0551 - val_loss: 0.0024 - val_mae: 0.0510
# Epoch 64/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0030 - mae: 0.0551 - val_loss: 0.0024 - val_mae: 0.0510
# Epoch 64/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0542 - val_loss: 0.0024 - val_mae: 0.0521
# Epoch 65/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0542 - val_loss: 0.0024 - val_mae: 0.0521
# Epoch 65/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - mae: 0.0557 - val_loss: 0.0024 - val_mae: 0.0508
# Epoch 66/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - mae: 0.0557 - val_loss: 0.0024 - val_mae: 0.0508
# Epoch 66/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mae: 0.0555 - val_loss: 0.0024 - val_mae: 0.0513
# Epoch 67/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mae: 0.0555 - val_loss: 0.0024 - val_mae: 0.0513
# Epoch 67/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0028 - mae: 0.0540 - val_loss: 0.0023 - val_mae: 0.0505
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0028 - mae: 0.0540 - val_loss: 0.0023 - val_mae: 0.0505
# Epoch 68/150
# Epoch 68/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0029 - mae: 0.0548 - val_loss: 0.0024 - val_mae: 0.0509
# Epoch 69/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0029 - mae: 0.0548 - val_loss: 0.0024 - val_mae: 0.0509
# Epoch 69/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0539 - val_loss: 0.0024 - val_mae: 0.0522
# Epoch 70/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0539 - val_loss: 0.0024 - val_mae: 0.0522
# Epoch 70/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0028 - mae: 0.0538 - val_loss: 0.0023 - val_mae: 0.0507
# Epoch 71/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0028 - mae: 0.0538 - val_loss: 0.0023 - val_mae: 0.0507
# Epoch 71/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0029 - mae: 0.0545 - val_loss: 0.0024 - val_mae: 0.0516
# Epoch 72/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0029 - mae: 0.0545 - val_loss: 0.0024 - val_mae: 0.0516
# Epoch 72/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0029 - mae: 0.0538 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 73/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0029 - mae: 0.0538 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 73/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mae: 0.0529 - val_loss: 0.0023 - val_mae: 0.0503
# Epoch 74/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mae: 0.0529 - val_loss: 0.0023 - val_mae: 0.0503
# Epoch 74/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - mae: 0.0551 - val_loss: 0.0024 - val_mae: 0.0517
# Epoch 75/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - mae: 0.0551 - val_loss: 0.0024 - val_mae: 0.0517
# Epoch 75/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0028 - mae: 0.0533 - val_loss: 0.0022 - val_mae: 0.0488
# Epoch 76/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0028 - mae: 0.0533 - val_loss: 0.0022 - val_mae: 0.0488
# Epoch 76/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0532 - val_loss: 0.0023 - val_mae: 0.0497
# Epoch 77/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0532 - val_loss: 0.0023 - val_mae: 0.0497
# Epoch 77/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0028 - mae: 0.0520 - val_loss: 0.0022 - val_mae: 0.0488
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0028 - mae: 0.0520 - val_loss: 0.0022 - val_mae: 0.0488
# Epoch 78/150
# Epoch 78/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0029 - mae: 0.0546 - val_loss: 0.0023 - val_mae: 0.0498
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0029 - mae: 0.0546 - val_loss: 0.0023 - val_mae: 0.0498
# Epoch 79/150
# Epoch 79/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0028 - mae: 0.0540 - val_loss: 0.0024 - val_mae: 0.0508
# Epoch 80/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0028 - mae: 0.0540 - val_loss: 0.0024 - val_mae: 0.0508
# Epoch 80/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0028 - mae: 0.0524 - val_loss: 0.0023 - val_mae: 0.0506
# Epoch 81/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0028 - mae: 0.0524 - val_loss: 0.0023 - val_mae: 0.0506
# Epoch 81/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0530 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 82/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0530 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 82/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mae: 0.0531 - val_loss: 0.0023 - val_mae: 0.0504
# Epoch 83/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mae: 0.0531 - val_loss: 0.0023 - val_mae: 0.0504
# Epoch 83/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mae: 0.0524 - val_loss: 0.0023 - val_mae: 0.0496
# Epoch 84/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mae: 0.0524 - val_loss: 0.0023 - val_mae: 0.0496
# Epoch 84/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0027 - mae: 0.0513 - val_loss: 0.0023 - val_mae: 0.0503
# Epoch 85/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0027 - mae: 0.0513 - val_loss: 0.0023 - val_mae: 0.0503
# Epoch 85/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0028 - mae: 0.0535 - val_loss: 0.0023 - val_mae: 0.0493
# Epoch 86/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0028 - mae: 0.0535 - val_loss: 0.0023 - val_mae: 0.0493
# Epoch 86/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0518 - val_loss: 0.0022 - val_mae: 0.0490
# Epoch 87/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0518 - val_loss: 0.0022 - val_mae: 0.0490
# Epoch 87/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0028 - mae: 0.0534 - val_loss: 0.0023 - val_mae: 0.0504
# Epoch 88/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0028 - mae: 0.0534 - val_loss: 0.0023 - val_mae: 0.0504
# Epoch 88/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0027 - mae: 0.0526 - val_loss: 0.0023 - val_mae: 0.0505
# Epoch 89/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0027 - mae: 0.0526 - val_loss: 0.0023 - val_mae: 0.0505
# Epoch 89/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0529 - val_loss: 0.0023 - val_mae: 0.0497
# Epoch 90/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0529 - val_loss: 0.0023 - val_mae: 0.0497
# Epoch 90/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0517 - val_loss: 0.0022 - val_mae: 0.0484
# Epoch 91/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0517 - val_loss: 0.0022 - val_mae: 0.0484
# Epoch 91/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0026 - mae: 0.0513 - val_loss: 0.0022 - val_mae: 0.0480
# Epoch 92/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0026 - mae: 0.0513 - val_loss: 0.0022 - val_mae: 0.0480
# Epoch 92/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0027 - mae: 0.0517 - val_loss: 0.0022 - val_mae: 0.0491
# Epoch 93/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0027 - mae: 0.0517 - val_loss: 0.0022 - val_mae: 0.0491
# Epoch 93/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0027 - mae: 0.0535 - val_loss: 0.0023 - val_mae: 0.0497
# Epoch 94/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0027 - mae: 0.0535 - val_loss: 0.0023 - val_mae: 0.0497
# Epoch 94/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0027 - mae: 0.0522 - val_loss: 0.0023 - val_mae: 0.0488
# Epoch 95/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0027 - mae: 0.0522 - val_loss: 0.0023 - val_mae: 0.0488
# Epoch 95/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0028 - mae: 0.0525 - val_loss: 0.0022 - val_mae: 0.0486
# Epoch 96/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0028 - mae: 0.0525 - val_loss: 0.0022 - val_mae: 0.0486
# Epoch 96/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0027 - mae: 0.0521 - val_loss: 0.0023 - val_mae: 0.0507
# Epoch 97/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0027 - mae: 0.0521 - val_loss: 0.0023 - val_mae: 0.0507
# Epoch 97/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0026 - mae: 0.0528 - val_loss: 0.0023 - val_mae: 0.0502
# Epoch 98/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0026 - mae: 0.0528 - val_loss: 0.0023 - val_mae: 0.0502
# Epoch 98/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0028 - mae: 0.0525 - val_loss: 0.0022 - val_mae: 0.0483
# Epoch 99/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0028 - mae: 0.0525 - val_loss: 0.0022 - val_mae: 0.0483
# Epoch 99/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0026 - mae: 0.0513 - val_loss: 0.0023 - val_mae: 0.0492
# Epoch 100/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0026 - mae: 0.0513 - val_loss: 0.0023 - val_mae: 0.0492
# Epoch 100/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0026 - mae: 0.0518 - val_loss: 0.0022 - val_mae: 0.0497
# Epoch 101/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0026 - mae: 0.0518 - val_loss: 0.0022 - val_mae: 0.0497
# Epoch 101/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0027 - mae: 0.0530 - val_loss: 0.0023 - val_mae: 0.0501
# Epoch 102/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0027 - mae: 0.0530 - val_loss: 0.0023 - val_mae: 0.0501
# Epoch 102/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0024 - mae: 0.0502 - val_loss: 0.0023 - val_mae: 0.0506
# Epoch 103/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0024 - mae: 0.0502 - val_loss: 0.0023 - val_mae: 0.0506
# Epoch 103/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0026 - mae: 0.0506 - val_loss: 0.0022 - val_mae: 0.0477
# Epoch 104/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0026 - mae: 0.0506 - val_loss: 0.0022 - val_mae: 0.0477
# Epoch 104/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - mae: 0.0517 - val_loss: 0.0022 - val_mae: 0.0494
# Epoch 105/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - mae: 0.0517 - val_loss: 0.0022 - val_mae: 0.0494
# Epoch 105/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0028 - mae: 0.0524 - val_loss: 0.0022 - val_mae: 0.0497
# Epoch 106/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0028 - mae: 0.0524 - val_loss: 0.0022 - val_mae: 0.0497
# Epoch 106/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0522 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 107/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0522 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 107/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0503 - val_loss: 0.0023 - val_mae: 0.0489
# Epoch 108/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0503 - val_loss: 0.0023 - val_mae: 0.0489
# Epoch 108/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0026 - mae: 0.0508 - val_loss: 0.0022 - val_mae: 0.0483
# Epoch 109/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0026 - mae: 0.0508 - val_loss: 0.0022 - val_mae: 0.0483
# Epoch 109/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0509 - val_loss: 0.0022 - val_mae: 0.0485
# Epoch 110/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0026 - mae: 0.0509 - val_loss: 0.0022 - val_mae: 0.0485
# Epoch 110/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0502 - val_loss: 0.0023 - val_mae: 0.0503
# Epoch 111/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0502 - val_loss: 0.0023 - val_mae: 0.0503
# Epoch 111/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - mae: 0.0509 - val_loss: 0.0023 - val_mae: 0.0488
# Epoch 112/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - mae: 0.0509 - val_loss: 0.0023 - val_mae: 0.0488
# Epoch 112/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - mae: 0.0515 - val_loss: 0.0022 - val_mae: 0.0484
# Epoch 113/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - mae: 0.0515 - val_loss: 0.0022 - val_mae: 0.0484
# Epoch 113/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - mae: 0.0513 - val_loss: 0.0023 - val_mae: 0.0498
# Epoch 114/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - mae: 0.0513 - val_loss: 0.0023 - val_mae: 0.0498
# Epoch 114/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0518 - val_loss: 0.0022 - val_mae: 0.0491
# Epoch 115/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0518 - val_loss: 0.0022 - val_mae: 0.0491
# Epoch 115/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0027 - mae: 0.0519 - val_loss: 0.0022 - val_mae: 0.0492
# Epoch 116/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0027 - mae: 0.0519 - val_loss: 0.0022 - val_mae: 0.0492
# Epoch 116/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0024 - mae: 0.0502 - val_loss: 0.0022 - val_mae: 0.0487
# Epoch 117/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0024 - mae: 0.0502 - val_loss: 0.0022 - val_mae: 0.0487
# Epoch 117/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0026 - mae: 0.0509 - val_loss: 0.0022 - val_mae: 0.0480
# Epoch 118/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0026 - mae: 0.0509 - val_loss: 0.0022 - val_mae: 0.0480
# Epoch 118/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0025 - mae: 0.0500 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 119/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0025 - mae: 0.0500 - val_loss: 0.0023 - val_mae: 0.0499
# Epoch 119/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0509 - val_loss: 0.0023 - val_mae: 0.0498
# Epoch 120/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - mae: 0.0509 - val_loss: 0.0023 - val_mae: 0.0498
# Epoch 120/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0025 - mae: 0.0504 - val_loss: 0.0023 - val_mae: 0.0486
# Epoch 121/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0025 - mae: 0.0504 - val_loss: 0.0023 - val_mae: 0.0486
# Epoch 121/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - mae: 0.0499 - val_loss: 0.0022 - val_mae: 0.0483
# Epoch 122/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - mae: 0.0499 - val_loss: 0.0022 - val_mae: 0.0483
# Epoch 122/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0024 - mae: 0.0493 - val_loss: 0.0023 - val_mae: 0.0494
# Epoch 123/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0024 - mae: 0.0493 - val_loss: 0.0023 - val_mae: 0.0494
# Epoch 123/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0026 - mae: 0.0512 - val_loss: 0.0022 - val_mae: 0.0488
# Epoch 124/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0026 - mae: 0.0512 - val_loss: 0.0022 - val_mae: 0.0488
# Epoch 124/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0025 - mae: 0.0496 - val_loss: 0.0022 - val_mae: 0.0485
# Epoch 125/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0025 - mae: 0.0496 - val_loss: 0.0022 - val_mae: 0.0485
# Epoch 125/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0025 - mae: 0.0509 - val_loss: 0.0022 - val_mae: 0.0484
# Epoch 126/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0025 - mae: 0.0509 - val_loss: 0.0022 - val_mae: 0.0484
# Epoch 126/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025 - mae: 0.0505 - val_loss: 0.0022 - val_mae: 0.0496
# Epoch 127/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025 - mae: 0.0505 - val_loss: 0.0022 - val_mae: 0.0496
# Epoch 127/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - mae: 0.0504 - val_loss: 0.0022 - val_mae: 0.0489
# Epoch 128/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - mae: 0.0504 - val_loss: 0.0022 - val_mae: 0.0489
# Epoch 128/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0025 - mae: 0.0514 - val_loss: 0.0022 - val_mae: 0.0490
# Epoch 129/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0025 - mae: 0.0514 - val_loss: 0.0022 - val_mae: 0.0490
# Epoch 129/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0491 - val_loss: 0.0023 - val_mae: 0.0495
# Epoch 130/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0491 - val_loss: 0.0023 - val_mae: 0.0495
# Epoch 130/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - mae: 0.0491 - val_loss: 0.0022 - val_mae: 0.0482
# Epoch 131/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - mae: 0.0491 - val_loss: 0.0022 - val_mae: 0.0482
# Epoch 131/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0503 - val_loss: 0.0023 - val_mae: 0.0495
# Epoch 132/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mae: 0.0503 - val_loss: 0.0023 - val_mae: 0.0495
# Epoch 132/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - mae: 0.0488 - val_loss: 0.0023 - val_mae: 0.0491
# Epoch 133/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - mae: 0.0488 - val_loss: 0.0023 - val_mae: 0.0491
# Epoch 133/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0025 - mae: 0.0494 - val_loss: 0.0023 - val_mae: 0.0502
# Epoch 133: early stopping
# Restoring model weights from the end of the best epoch: 103.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0025 - mae: 0.0494 - val_loss: 0.0023 - val_mae: 0.0502
# Epoch 133: early stopping
# Restoring model weights from the end of the best epoch: 103.
#
# ==================================================
# Training LSTM Lean – Kuchen (WG5)
# ==================================================
# Epoch 1/150
#
# ==================================================
# Training LSTM Lean – Kuchen (WG5)
# ==================================================
# Epoch 1/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0034 - mae: 0.0520 - val_loss: 0.0015 - val_mae: 0.0306
# Epoch 2/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0034 - mae: 0.0520 - val_loss: 0.0015 - val_mae: 0.0306
# Epoch 2/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0015 - val_mae: 0.0278
# Epoch 3/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0015 - val_mae: 0.0278
# Epoch 3/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0020 - mae: 0.0307 - val_loss: 0.0015 - val_mae: 0.0280
# Epoch 4/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0020 - mae: 0.0307 - val_loss: 0.0015 - val_mae: 0.0280
# Epoch 4/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0019 - mae: 0.0301 - val_loss: 0.0014 - val_mae: 0.0271
# Epoch 5/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0019 - mae: 0.0301 - val_loss: 0.0014 - val_mae: 0.0271
# Epoch 5/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mae: 0.0292 - val_loss: 0.0014 - val_mae: 0.0264
# Epoch 6/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mae: 0.0292 - val_loss: 0.0014 - val_mae: 0.0264
# Epoch 6/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mae: 0.0286 - val_loss: 0.0014 - val_mae: 0.0262
# Epoch 7/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mae: 0.0286 - val_loss: 0.0014 - val_mae: 0.0262
# Epoch 7/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - mae: 0.0276 - val_loss: 0.0014 - val_mae: 0.0237
# Epoch 8/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - mae: 0.0276 - val_loss: 0.0014 - val_mae: 0.0237
# Epoch 8/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - mae: 0.0267 - val_loss: 0.0013 - val_mae: 0.0232
# Epoch 9/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - mae: 0.0267 - val_loss: 0.0013 - val_mae: 0.0232
# Epoch 9/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mae: 0.0265 - val_loss: 0.0013 - val_mae: 0.0229
# Epoch 10/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mae: 0.0265 - val_loss: 0.0013 - val_mae: 0.0229
# Epoch 10/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mae: 0.0260 - val_loss: 0.0013 - val_mae: 0.0224
# Epoch 11/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mae: 0.0260 - val_loss: 0.0013 - val_mae: 0.0224
# Epoch 11/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mae: 0.0260 - val_loss: 0.0013 - val_mae: 0.0229
# Epoch 12/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mae: 0.0260 - val_loss: 0.0013 - val_mae: 0.0229
# Epoch 12/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mae: 0.0251 - val_loss: 0.0012 - val_mae: 0.0223
# Epoch 13/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mae: 0.0251 - val_loss: 0.0012 - val_mae: 0.0223
# Epoch 13/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mae: 0.0255 - val_loss: 0.0012 - val_mae: 0.0219
# Epoch 14/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mae: 0.0255 - val_loss: 0.0012 - val_mae: 0.0219
# Epoch 14/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - mae: 0.0258 - val_loss: 0.0012 - val_mae: 0.0223
# Epoch 15/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - mae: 0.0258 - val_loss: 0.0012 - val_mae: 0.0223
# Epoch 15/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mae: 0.0250 - val_loss: 0.0011 - val_mae: 0.0217
# Epoch 16/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mae: 0.0250 - val_loss: 0.0011 - val_mae: 0.0217
# Epoch 16/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0249 - val_loss: 0.0011 - val_mae: 0.0221
# Epoch 17/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0249 - val_loss: 0.0011 - val_mae: 0.0221
# Epoch 17/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0222
# Epoch 18/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0222
# Epoch 18/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - mae: 0.0257 - val_loss: 9.5765e-04 - val_mae: 0.0222
# Epoch 19/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - mae: 0.0257 - val_loss: 9.5765e-04 - val_mae: 0.0222
# Epoch 19/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.8081e-04 - mae: 0.0252 - val_loss: 8.0611e-04 - val_mae: 0.0211
# Epoch 20/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.8081e-04 - mae: 0.0252 - val_loss: 8.0611e-04 - val_mae: 0.0211
# Epoch 20/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0010 - mae: 0.0250 - val_loss: 7.2215e-04 - val_mae: 0.0221
# Epoch 21/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0010 - mae: 0.0250 - val_loss: 7.2215e-04 - val_mae: 0.0221
# Epoch 21/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.4865e-04 - mae: 0.0247 - val_loss: 5.7259e-04 - val_mae: 0.0206
# Epoch 22/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.4865e-04 - mae: 0.0247 - val_loss: 5.7259e-04 - val_mae: 0.0206
# Epoch 22/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.9879e-04 - mae: 0.0238 - val_loss: 5.0816e-04 - val_mae: 0.0206
# Epoch 23/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.9879e-04 - mae: 0.0238 - val_loss: 5.0816e-04 - val_mae: 0.0206
# Epoch 23/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.6855e-04 - mae: 0.0229 - val_loss: 4.7461e-04 - val_mae: 0.0200
# Epoch 24/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.6855e-04 - mae: 0.0229 - val_loss: 4.7461e-04 - val_mae: 0.0200
# Epoch 24/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.3304e-04 - mae: 0.0229 - val_loss: 4.1249e-04 - val_mae: 0.0200
# Epoch 25/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.3304e-04 - mae: 0.0229 - val_loss: 4.1249e-04 - val_mae: 0.0200
# Epoch 25/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3448e-04 - mae: 0.0232 - val_loss: 3.9335e-04 - val_mae: 0.0194
# Epoch 26/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3448e-04 - mae: 0.0232 - val_loss: 3.9335e-04 - val_mae: 0.0194
# Epoch 26/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5663e-04 - mae: 0.0225 - val_loss: 3.8331e-04 - val_mae: 0.0191
# Epoch 27/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5663e-04 - mae: 0.0225 - val_loss: 3.8331e-04 - val_mae: 0.0191
# Epoch 27/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5658e-04 - mae: 0.0215 - val_loss: 3.4300e-04 - val_mae: 0.0196
# Epoch 28/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5658e-04 - mae: 0.0215 - val_loss: 3.4300e-04 - val_mae: 0.0196
# Epoch 28/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4384e-04 - mae: 0.0216 - val_loss: 3.8733e-04 - val_mae: 0.0194
# Epoch 29/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4384e-04 - mae: 0.0216 - val_loss: 3.8733e-04 - val_mae: 0.0194
# Epoch 29/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.1495e-04 - mae: 0.0222 - val_loss: 3.4062e-04 - val_mae: 0.0192
# Epoch 30/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.1495e-04 - mae: 0.0222 - val_loss: 3.4062e-04 - val_mae: 0.0192
# Epoch 30/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1997e-04 - mae: 0.0220 - val_loss: 3.4209e-04 - val_mae: 0.0193
# Epoch 31/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1997e-04 - mae: 0.0220 - val_loss: 3.4209e-04 - val_mae: 0.0193
# Epoch 31/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9692e-04 - mae: 0.0222 - val_loss: 3.2018e-04 - val_mae: 0.0194
# Epoch 32/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9692e-04 - mae: 0.0222 - val_loss: 3.2018e-04 - val_mae: 0.0194
# Epoch 32/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6877e-04 - mae: 0.0219 - val_loss: 3.2306e-04 - val_mae: 0.0195
# Epoch 33/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6877e-04 - mae: 0.0219 - val_loss: 3.2306e-04 - val_mae: 0.0195
# Epoch 33/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4865e-04 - mae: 0.0218 - val_loss: 3.3019e-04 - val_mae: 0.0193
# Epoch 34/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4865e-04 - mae: 0.0218 - val_loss: 3.3019e-04 - val_mae: 0.0193
# Epoch 34/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0417e-04 - mae: 0.0214 - val_loss: 3.1571e-04 - val_mae: 0.0193
# Epoch 35/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0417e-04 - mae: 0.0214 - val_loss: 3.1571e-04 - val_mae: 0.0193
# Epoch 35/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9963e-04 - mae: 0.0212 - val_loss: 3.0268e-04 - val_mae: 0.0185
# Epoch 36/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9963e-04 - mae: 0.0212 - val_loss: 3.0268e-04 - val_mae: 0.0185
# Epoch 36/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4553e-04 - mae: 0.0203 - val_loss: 3.1883e-04 - val_mae: 0.0197
# Epoch 37/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4553e-04 - mae: 0.0203 - val_loss: 3.1883e-04 - val_mae: 0.0197
# Epoch 37/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0675e-04 - mae: 0.0225 - val_loss: 3.0092e-04 - val_mae: 0.0185
# Epoch 38/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0675e-04 - mae: 0.0225 - val_loss: 3.0092e-04 - val_mae: 0.0185
# Epoch 38/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.6494e-04 - mae: 0.0214 - val_loss: 3.2905e-04 - val_mae: 0.0189
# Epoch 39/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.6494e-04 - mae: 0.0214 - val_loss: 3.2905e-04 - val_mae: 0.0189
# Epoch 39/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7444e-04 - mae: 0.0215 - val_loss: 3.1102e-04 - val_mae: 0.0194
# Epoch 40/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7444e-04 - mae: 0.0215 - val_loss: 3.1102e-04 - val_mae: 0.0194
# Epoch 40/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0672e-04 - mae: 0.0215 - val_loss: 3.2310e-04 - val_mae: 0.0197
# Epoch 41/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0672e-04 - mae: 0.0215 - val_loss: 3.2310e-04 - val_mae: 0.0197
# Epoch 41/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8674e-04 - mae: 0.0205 - val_loss: 3.6294e-04 - val_mae: 0.0200
# Epoch 42/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8674e-04 - mae: 0.0205 - val_loss: 3.6294e-04 - val_mae: 0.0200
# Epoch 42/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7172e-04 - mae: 0.0203 - val_loss: 3.0868e-04 - val_mae: 0.0183
# Epoch 43/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7172e-04 - mae: 0.0203 - val_loss: 3.0868e-04 - val_mae: 0.0183
# Epoch 43/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.6035e-04 - mae: 0.0209 - val_loss: 4.0387e-04 - val_mae: 0.0207
# Epoch 44/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.6035e-04 - mae: 0.0209 - val_loss: 4.0387e-04 - val_mae: 0.0207
# Epoch 44/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6935e-04 - mae: 0.0208 - val_loss: 3.1109e-04 - val_mae: 0.0188
# Epoch 45/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6935e-04 - mae: 0.0208 - val_loss: 3.1109e-04 - val_mae: 0.0188
# Epoch 45/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.6930e-04 - mae: 0.0212 - val_loss: 3.0275e-04 - val_mae: 0.0189
# Epoch 46/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.6930e-04 - mae: 0.0212 - val_loss: 3.0275e-04 - val_mae: 0.0189
# Epoch 46/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9172e-04 - mae: 0.0211 - val_loss: 3.3590e-04 - val_mae: 0.0199
# Epoch 47/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9172e-04 - mae: 0.0211 - val_loss: 3.3590e-04 - val_mae: 0.0199
# Epoch 47/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6231e-04 - mae: 0.0202 - val_loss: 3.0646e-04 - val_mae: 0.0187
# Epoch 48/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6231e-04 - mae: 0.0202 - val_loss: 3.0646e-04 - val_mae: 0.0187
# Epoch 48/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8783e-04 - mae: 0.0200 - val_loss: 3.1242e-04 - val_mae: 0.0184
# Epoch 49/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8783e-04 - mae: 0.0200 - val_loss: 3.1242e-04 - val_mae: 0.0184
# Epoch 49/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9579e-04 - mae: 0.0204 - val_loss: 3.1869e-04 - val_mae: 0.0196
# Epoch 50/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9579e-04 - mae: 0.0204 - val_loss: 3.1869e-04 - val_mae: 0.0196
# Epoch 50/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8591e-04 - mae: 0.0210 - val_loss: 3.3049e-04 - val_mae: 0.0197
# Epoch 51/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8591e-04 - mae: 0.0210 - val_loss: 3.3049e-04 - val_mae: 0.0197
# Epoch 51/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.9540e-04 - mae: 0.0200 - val_loss: 3.3335e-04 - val_mae: 0.0195
# Epoch 52/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.9540e-04 - mae: 0.0200 - val_loss: 3.3335e-04 - val_mae: 0.0195
# Epoch 52/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9236e-04 - mae: 0.0201 - val_loss: 3.0817e-04 - val_mae: 0.0190
# Epoch 53/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9236e-04 - mae: 0.0201 - val_loss: 3.0817e-04 - val_mae: 0.0190
# Epoch 53/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4323e-04 - mae: 0.0211 - val_loss: 3.3851e-04 - val_mae: 0.0199
# Epoch 54/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4323e-04 - mae: 0.0211 - val_loss: 3.3851e-04 - val_mae: 0.0199
# Epoch 54/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0274e-04 - mae: 0.0203 - val_loss: 2.9606e-04 - val_mae: 0.0185
# Epoch 55/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0274e-04 - mae: 0.0203 - val_loss: 2.9606e-04 - val_mae: 0.0185
# Epoch 55/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1131e-04 - mae: 0.0205 - val_loss: 3.1695e-04 - val_mae: 0.0196
# Epoch 56/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1131e-04 - mae: 0.0205 - val_loss: 3.1695e-04 - val_mae: 0.0196
# Epoch 56/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4154e-04 - mae: 0.0213 - val_loss: 3.0320e-04 - val_mae: 0.0188
# Epoch 57/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4154e-04 - mae: 0.0213 - val_loss: 3.0320e-04 - val_mae: 0.0188
# Epoch 57/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0770e-04 - mae: 0.0205 - val_loss: 3.2045e-04 - val_mae: 0.0190
# Epoch 58/150
# ...
# Epoch 90/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2825e-04 - mae: 0.0203 - val_loss: 2.9949e-04 - val_mae: 0.0190
# Epoch 90/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6827e-04 - mae: 0.0194 - val_loss: 2.8669e-04 - val_mae: 0.0183
# Epoch 91/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6827e-04 - mae: 0.0194 - val_loss: 2.8669e-04 - val_mae: 0.0183
# Epoch 91/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9545e-04 - mae: 0.0197 - val_loss: 3.0350e-04 - val_mae: 0.0185
# Epoch 92/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9545e-04 - mae: 0.0197 - val_loss: 3.0350e-04 - val_mae: 0.0185
# Epoch 92/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6588e-04 - mae: 0.0196 - val_loss: 2.8685e-04 - val_mae: 0.0182
# Epoch 93/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6588e-04 - mae: 0.0196 - val_loss: 2.8685e-04 - val_mae: 0.0182
# Epoch 93/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1116e-04 - mae: 0.0199 - val_loss: 3.3058e-04 - val_mae: 0.0194
# Epoch 94/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1116e-04 - mae: 0.0199 - val_loss: 3.3058e-04 - val_mae: 0.0194
# Epoch 94/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5212e-04 - mae: 0.0197 - val_loss: 2.9936e-04 - val_mae: 0.0185
# Epoch 95/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5212e-04 - mae: 0.0197 - val_loss: 2.9936e-04 - val_mae: 0.0185
# Epoch 95/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9978e-04 - mae: 0.0198 - val_loss: 3.0193e-04 - val_mae: 0.0191
# Epoch 96/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9978e-04 - mae: 0.0198 - val_loss: 3.0193e-04 - val_mae: 0.0191
# Epoch 96/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4072e-04 - mae: 0.0197 - val_loss: 2.9172e-04 - val_mae: 0.0186
# Epoch 97/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4072e-04 - mae: 0.0197 - val_loss: 2.9172e-04 - val_mae: 0.0186
# Epoch 97/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7799e-04 - mae: 0.0195 - val_loss: 2.9787e-04 - val_mae: 0.0187
# Epoch 98/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7799e-04 - mae: 0.0195 - val_loss: 2.9787e-04 - val_mae: 0.0187
# Epoch 98/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4315e-04 - mae: 0.0197 - val_loss: 2.8833e-04 - val_mae: 0.0183
# Epoch 99/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4315e-04 - mae: 0.0197 - val_loss: 2.8833e-04 - val_mae: 0.0183
# Epoch 99/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7233e-04 - mae: 0.0196 - val_loss: 2.9826e-04 - val_mae: 0.0182
# Epoch 100/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7233e-04 - mae: 0.0196 - val_loss: 2.9826e-04 - val_mae: 0.0182
# Epoch 100/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4334e-04 - mae: 0.0196 - val_loss: 2.8852e-04 - val_mae: 0.0185
# Epoch 101/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4334e-04 - mae: 0.0196 - val_loss: 2.8852e-04 - val_mae: 0.0185
# Epoch 101/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4920e-04 - mae: 0.0203 - val_loss: 2.9794e-04 - val_mae: 0.0185
# Epoch 102/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4920e-04 - mae: 0.0203 - val_loss: 2.9794e-04 - val_mae: 0.0185
# Epoch 102/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0621e-04 - mae: 0.0189 - val_loss: 2.9835e-04 - val_mae: 0.0185
# Epoch 103/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0621e-04 - mae: 0.0189 - val_loss: 2.9835e-04 - val_mae: 0.0185
# Epoch 103/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3011e-04 - mae: 0.0191 - val_loss: 3.3825e-04 - val_mae: 0.0191
# Epoch 104/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3011e-04 - mae: 0.0191 - val_loss: 3.3825e-04 - val_mae: 0.0191
# Epoch 104/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1180e-04 - mae: 0.0193 - val_loss: 3.1607e-04 - val_mae: 0.0196
# Epoch 105/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1180e-04 - mae: 0.0193 - val_loss: 3.1607e-04 - val_mae: 0.0196
# Epoch 105/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2432e-04 - mae: 0.0191 - val_loss: 2.9295e-04 - val_mae: 0.0182
# Epoch 106/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2432e-04 - mae: 0.0191 - val_loss: 2.9295e-04 - val_mae: 0.0182
# Epoch 106/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 3.8642e-04 - mae: 0.0198 - val_loss: 3.0379e-04 - val_mae: 0.0187
# Epoch 107/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 3.8642e-04 - mae: 0.0198 - val_loss: 3.0379e-04 - val_mae: 0.0187
# Epoch 107/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3512e-04 - mae: 0.0191 - val_loss: 3.0403e-04 - val_mae: 0.0192
# Epoch 108/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3512e-04 - mae: 0.0191 - val_loss: 3.0403e-04 - val_mae: 0.0192
# Epoch 108/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3873e-04 - mae: 0.0195 - val_loss: 2.8657e-04 - val_mae: 0.0181
# Epoch 109/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3873e-04 - mae: 0.0195 - val_loss: 2.8657e-04 - val_mae: 0.0181
# Epoch 109/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6029e-04 - mae: 0.0202 - val_loss: 2.8935e-04 - val_mae: 0.0185
# Epoch 110/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6029e-04 - mae: 0.0202 - val_loss: 2.8935e-04 - val_mae: 0.0185
# Epoch 110/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1257e-04 - mae: 0.0189 - val_loss: 2.8788e-04 - val_mae: 0.0182
# Epoch 111/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1257e-04 - mae: 0.0189 - val_loss: 2.8788e-04 - val_mae: 0.0182
# Epoch 111/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2042e-04 - mae: 0.0191 - val_loss: 2.8834e-04 - val_mae: 0.0183
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2042e-04 - mae: 0.0191 - val_loss: 2.8834e-04 - val_mae: 0.0183
# Epoch 112/150
# Epoch 112/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1873e-04 - mae: 0.0199 - val_loss: 2.9153e-04 - val_mae: 0.0182
# Epoch 113/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1873e-04 - mae: 0.0199 - val_loss: 2.9153e-04 - val_mae: 0.0182
# Epoch 113/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1602e-04 - mae: 0.0200 - val_loss: 2.9975e-04 - val_mae: 0.0189
# Epoch 114/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1602e-04 - mae: 0.0200 - val_loss: 2.9975e-04 - val_mae: 0.0189
# Epoch 114/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2484e-04 - mae: 0.0199 - val_loss: 2.9257e-04 - val_mae: 0.0185
# Epoch 115/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2484e-04 - mae: 0.0199 - val_loss: 2.9257e-04 - val_mae: 0.0185
# Epoch 115/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.8124e-04 - mae: 0.0205 - val_loss: 2.9940e-04 - val_mae: 0.0191
# Epoch 116/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.8124e-04 - mae: 0.0205 - val_loss: 2.9940e-04 - val_mae: 0.0191
# Epoch 116/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3905e-04 - mae: 0.0194 - val_loss: 2.8193e-04 - val_mae: 0.0180
# Epoch 117/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3905e-04 - mae: 0.0194 - val_loss: 2.8193e-04 - val_mae: 0.0180
# Epoch 117/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9693e-04 - mae: 0.0199 - val_loss: 3.2623e-04 - val_mae: 0.0196
# Epoch 118/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9693e-04 - mae: 0.0199 - val_loss: 3.2623e-04 - val_mae: 0.0196
# Epoch 118/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2048e-04 - mae: 0.0200 - val_loss: 2.9811e-04 - val_mae: 0.0190
# Epoch 119/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2048e-04 - mae: 0.0200 - val_loss: 2.9811e-04 - val_mae: 0.0190
# Epoch 119/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5341e-04 - mae: 0.0201 - val_loss: 2.9023e-04 - val_mae: 0.0184
# Epoch 120/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5341e-04 - mae: 0.0201 - val_loss: 2.9023e-04 - val_mae: 0.0184
# Epoch 120/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0284e-04 - mae: 0.0200 - val_loss: 2.8182e-04 - val_mae: 0.0181
# Epoch 121/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0284e-04 - mae: 0.0200 - val_loss: 2.8182e-04 - val_mae: 0.0181
# Epoch 121/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1713e-04 - mae: 0.0191 - val_loss: 3.1044e-04 - val_mae: 0.0196
# Epoch 122/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1713e-04 - mae: 0.0191 - val_loss: 3.1044e-04 - val_mae: 0.0196
# Epoch 122/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4709e-04 - mae: 0.0201 - val_loss: 2.9752e-04 - val_mae: 0.0189
# Epoch 123/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4709e-04 - mae: 0.0201 - val_loss: 2.9752e-04 - val_mae: 0.0189
# Epoch 123/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.9165e-04 - mae: 0.0201 - val_loss: 2.9093e-04 - val_mae: 0.0185
# Epoch 124/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.9165e-04 - mae: 0.0201 - val_loss: 2.9093e-04 - val_mae: 0.0185
# Epoch 124/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9740e-04 - mae: 0.0193 - val_loss: 2.8451e-04 - val_mae: 0.0182
# Epoch 125/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9740e-04 - mae: 0.0193 - val_loss: 2.8451e-04 - val_mae: 0.0182
# Epoch 125/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0043e-04 - mae: 0.0187 - val_loss: 2.8668e-04 - val_mae: 0.0185
# Epoch 126/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0043e-04 - mae: 0.0187 - val_loss: 2.8668e-04 - val_mae: 0.0185
# Epoch 126/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5239e-04 - mae: 0.0190 - val_loss: 2.7557e-04 - val_mae: 0.0175
# Epoch 127/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5239e-04 - mae: 0.0190 - val_loss: 2.7557e-04 - val_mae: 0.0175
# Epoch 127/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5951e-04 - mae: 0.0194 - val_loss: 2.9997e-04 - val_mae: 0.0193
# Epoch 128/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5951e-04 - mae: 0.0194 - val_loss: 2.9997e-04 - val_mae: 0.0193
# Epoch 128/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.0284e-04 - mae: 0.0204 - val_loss: 2.8831e-04 - val_mae: 0.0186
# Epoch 129/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.0284e-04 - mae: 0.0204 - val_loss: 2.8831e-04 - val_mae: 0.0186
# Epoch 129/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2839e-04 - mae: 0.0196 - val_loss: 2.8825e-04 - val_mae: 0.0184
# Epoch 130/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2839e-04 - mae: 0.0196 - val_loss: 2.8825e-04 - val_mae: 0.0184
# Epoch 130/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2948e-04 - mae: 0.0197 - val_loss: 2.9218e-04 - val_mae: 0.0188
# Epoch 131/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2948e-04 - mae: 0.0197 - val_loss: 2.9218e-04 - val_mae: 0.0188
# Epoch 131/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3161e-04 - mae: 0.0192 - val_loss: 2.9366e-04 - val_mae: 0.0187
# Epoch 132/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3161e-04 - mae: 0.0192 - val_loss: 2.9366e-04 - val_mae: 0.0187
# Epoch 132/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1880e-04 - mae: 0.0191 - val_loss: 2.8696e-04 - val_mae: 0.0184
# Epoch 133/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1880e-04 - mae: 0.0191 - val_loss: 2.8696e-04 - val_mae: 0.0184
# Epoch 133/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6612e-04 - mae: 0.0195 - val_loss: 2.9222e-04 - val_mae: 0.0186
# Epoch 134/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6612e-04 - mae: 0.0195 - val_loss: 2.9222e-04 - val_mae: 0.0186
# Epoch 134/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2131e-04 - mae: 0.0197 - val_loss: 2.8855e-04 - val_mae: 0.0184
# Epoch 135/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2131e-04 - mae: 0.0197 - val_loss: 2.8855e-04 - val_mae: 0.0184
# Epoch 135/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1585e-04 - mae: 0.0191 - val_loss: 2.7980e-04 - val_mae: 0.0179
# Epoch 136/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1585e-04 - mae: 0.0191 - val_loss: 2.7980e-04 - val_mae: 0.0179
# Epoch 136/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2599e-04 - mae: 0.0194 - val_loss: 3.0193e-04 - val_mae: 0.0192
# Epoch 137/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2599e-04 - mae: 0.0194 - val_loss: 3.0193e-04 - val_mae: 0.0192
# Epoch 137/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4709e-04 - mae: 0.0196 - val_loss: 2.9431e-04 - val_mae: 0.0188
# Epoch 138/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4709e-04 - mae: 0.0196 - val_loss: 2.9431e-04 - val_mae: 0.0188
# Epoch 138/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1393e-04 - mae: 0.0195 - val_loss: 2.8393e-04 - val_mae: 0.0184
# Epoch 139/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1393e-04 - mae: 0.0195 - val_loss: 2.8393e-04 - val_mae: 0.0184
# Epoch 139/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2697e-04 - mae: 0.0190 - val_loss: 3.2203e-04 - val_mae: 0.0195
# Epoch 140/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2697e-04 - mae: 0.0190 - val_loss: 3.2203e-04 - val_mae: 0.0195
# Epoch 140/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6034e-04 - mae: 0.0192 - val_loss: 2.8754e-04 - val_mae: 0.0185
# Epoch 141/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6034e-04 - mae: 0.0192 - val_loss: 2.8754e-04 - val_mae: 0.0185
# Epoch 141/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1246e-04 - mae: 0.0185 - val_loss: 2.8931e-04 - val_mae: 0.0186
# Epoch 142/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1246e-04 - mae: 0.0185 - val_loss: 2.8931e-04 - val_mae: 0.0186
# Epoch 142/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0414e-04 - mae: 0.0190 - val_loss: 2.8202e-04 - val_mae: 0.0182
# Epoch 143/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0414e-04 - mae: 0.0190 - val_loss: 2.8202e-04 - val_mae: 0.0182
# Epoch 143/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6095e-04 - mae: 0.0191 - val_loss: 2.8293e-04 - val_mae: 0.0184
# Epoch 144/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6095e-04 - mae: 0.0191 - val_loss: 2.8293e-04 - val_mae: 0.0184
# Epoch 144/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5130e-04 - mae: 0.0194 - val_loss: 2.9978e-04 - val_mae: 0.0190
# Epoch 145/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5130e-04 - mae: 0.0194 - val_loss: 2.9978e-04 - val_mae: 0.0190
# Epoch 145/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.4047e-04 - mae: 0.0195 - val_loss: 2.7983e-04 - val_mae: 0.0181
# Epoch 146/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.4047e-04 - mae: 0.0195 - val_loss: 2.7983e-04 - val_mae: 0.0181
# Epoch 146/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2665e-04 - mae: 0.0189 - val_loss: 3.1178e-04 - val_mae: 0.0195
# Epoch 147/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2665e-04 - mae: 0.0189 - val_loss: 3.1178e-04 - val_mae: 0.0195
# Epoch 147/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0571e-04 - mae: 0.0188 - val_loss: 3.0076e-04 - val_mae: 0.0187
# Epoch 148/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0571e-04 - mae: 0.0188 - val_loss: 3.0076e-04 - val_mae: 0.0187
# Epoch 148/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4967e-04 - mae: 0.0190 - val_loss: 3.0086e-04 - val_mae: 0.0186
# Epoch 149/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4967e-04 - mae: 0.0190 - val_loss: 3.0086e-04 - val_mae: 0.0186
# Epoch 149/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9912e-04 - mae: 0.0198 - val_loss: 2.9936e-04 - val_mae: 0.0185
# Epoch 150/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9912e-04 - mae: 0.0198 - val_loss: 2.9936e-04 - val_mae: 0.0185
# Epoch 150/150
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9368e-04 - mae: 0.0194 - val_loss: 2.8698e-04 - val_mae: 0.0184
# Restoring model weights from the end of the best epoch: 126.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9368e-04 - mae: 0.0194 - val_loss: 2.8698e-04 - val_mae: 0.0184
# Restoring model weights from the end of the best epoch: 126.
#
# Parameter pro Modell: 9,057 (vs. 348k in v2 → 39x weniger!)
#
# Parameter pro Modell: 9,057 (vs. 348k in v2 → 39x weniger!)

# %%
# ============================================================
# LSTM – Trainingsverlauf visualisieren
# ============================================================

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Brötchen
axes[0].plot(history_wg2.history["loss"], label="Train Loss")
axes[0].plot(history_wg2.history["val_loss"], label="Val Loss")
axes[0].set_title("Trainingsverlauf – Brötchen (WG2)")
axes[0].set_xlabel("Epoche")
axes[0].set_ylabel("MSE Loss")
axes[0].legend()

# Kuchen
axes[1].plot(history_wg5.history["loss"], label="Train Loss")
axes[1].plot(history_wg5.history["val_loss"], label="Val Loss")
axes[1].set_title("Trainingsverlauf – Kuchen (WG5)")
axes[1].set_xlabel("Epoche")
axes[1].set_ylabel("MSE Loss")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# LSTM Lean – Vorhersagen + Evaluation
# ============================================================

# --- Brötchen (WG2) ---
y_pred_lstm_wg2_scaled = lstm_wg2.predict(X_test_lstm_wg2).flatten()
y_pred_lstm_wg2 = scaler_y_wg2.inverse_transform(
    y_pred_lstm_wg2_scaled.reshape(-1, 1)
).flatten()

y_true_lstm_wg2 = scaler_y_wg2.inverse_transform(
    y_test_lstm_wg2.reshape(-1, 1)
).flatten()

mae_lstm_wg2 = mean_absolute_error(y_true_lstm_wg2, y_pred_lstm_wg2)
rmse_lstm_wg2 = np.sqrt(mean_squared_error(y_true_lstm_wg2, y_pred_lstm_wg2))

# --- Kuchen (WG5) ---
y_pred_lstm_wg5_scaled = lstm_wg5.predict(X_test_lstm_wg5).flatten()
y_pred_lstm_wg5 = scaler_y_wg5.inverse_transform(
    y_pred_lstm_wg5_scaled.reshape(-1, 1)
).flatten()

y_true_lstm_wg5 = scaler_y_wg5.inverse_transform(
    y_test_lstm_wg5.reshape(-1, 1)
).flatten()

mae_lstm_wg5 = mean_absolute_error(y_true_lstm_wg5, y_pred_lstm_wg5)
rmse_lstm_wg5 = np.sqrt(mean_squared_error(y_true_lstm_wg5, y_pred_lstm_wg5))

# ============================================================
# Vergleich aller Modelle
# ============================================================
print("=" * 60)
print("MODELLVERGLEICH – Alle drei Modelle")
print("=" * 60)

print("\n--- Warengruppe 2 – Brötchen ---")
print(f"{'Modell':<25} {'MAE':>8} {'RMSE':>8}")
print("-" * 43)
print(f"{'Heuristik (lag_1W)':<25} {mae_heuristik_WG2:>8.2f} {rmse_heuristik_WG2:>8.2f}")
print(f"{'Lineare Regression':<25} {mae_lr_WG2:>8.2f} {rmse_lr_WG2:>8.2f}")
print(f"{'LSTM Lean':<25} {mae_lstm_wg2:>8.2f} {rmse_lstm_wg2:>8.2f}")

print(f"\n--- Warengruppe 5 – Kuchen ---")
print(f"{'Modell':<25} {'MAE':>8} {'RMSE':>8}")
print("-" * 43)
print(f"{'Heuristik (lag_1W)':<25} {mae_heuristik_WG5:>8.2f} {rmse_heuristik_WG5:>8.2f}")
print(f"{'Lineare Regression':<25} {mae_lr_WG5:>8.2f} {rmse_lr_WG5:>8.2f}")
print(f"{'LSTM Lean':<25} {mae_lstm_wg5:>8.2f} {rmse_lstm_wg5:>8.2f}")

print(f"\n--- Gesamt-RMSE (Durchschnitt WG2 + WG5) ---")
print(f"{'Heuristik':<25} {(rmse_heuristik_WG2 + rmse_heuristik_WG5) / 2:>8.2f}")
print(f"{'Lineare Regression':<25} {(rmse_lr_WG2 + rmse_lr_WG5) / 2:>8.2f}")
print(f"{'LSTM Lean':<25} {(rmse_lstm_wg2 + rmse_lstm_wg5) / 2:>8.2f}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step
# ============================================================
# MODELLVERGLEICH – Alle drei Modelle
# ============================================================
#
# --- Warengruppe 2 – Brötchen ---
# Modell                         MAE     RMSE
# -------------------------------------------
# Heuristik (lag_1W)           55.74    81.76
# Lineare Regression           45.10    60.77
# LSTM Lean                    34.71    46.70
#
# --- Warengruppe 5 – Kuchen ---
# Modell                         MAE     RMSE
# -------------------------------------------
# Heuristik (lag_1W)           55.60   117.16
# Lineare Regression           39.44    53.10
# LSTM Lean                    35.56    50.24
#
# --- Gesamt-RMSE (Durchschnitt WG2 + WG5) ---
# Heuristik                    99.46
# Lineare Regression           56.94
# LSTM Lean                    48.47
# ============================================================
# MODELLVERGLEICH – Alle drei Modelle
# ============================================================
#
# --- Warengruppe 2 – Brötchen ---
# Modell                         MAE     RMSE
# -------------------------------------------
# Heuristik (lag_1W)           55.74    81.76
# Lineare Regression           45.10    60.77
# LSTM Lean                    34.71    46.70
#
# --- Warengruppe 5 – Kuchen ---
# Modell                         MAE     RMSE
# -------------------------------------------
# Heuristik (lag_1W)           55.60   117.16
# Lineare Regression           39.44    53.10
# LSTM Lean                    35.56    50.24
#
# --- Gesamt-RMSE (Durchschnitt WG2 + WG5) ---
# Heuristik                    99.46
# Lineare Regression           56.94
# LSTM Lean                    48.47

# %%
# ============================================================
# LSTM – Residuenanalyse
# ============================================================

# Datumsreihe für Test – die Sequenzen starten bei den letzten LOOKBACK Tagen
# des Trainings und liefern Vorhersagen ab dem ersten Testtag
test_dates_wg2 = test_wg2["Datum"].values
test_dates_wg5 = test_wg5["Datum"].values

resid_lstm_wg2 = y_true_lstm_wg2 - y_pred_lstm_wg2
resid_lstm_wg5 = y_true_lstm_wg5 - y_pred_lstm_wg5

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# --- Brötchen: Residuen über die Zeit ---
axes[0, 0].plot(test_dates_wg2, resid_lstm_wg2, color="tab:green", alpha=0.7)
axes[0, 0].axhline(0, linestyle="--", color="gray")
axes[0, 0].set_title("Residuen über die Zeit – LSTM Brötchen (WG2)")
axes[0, 0].set_xlabel("Datum")
axes[0, 0].set_ylabel("Residuum (EUR)")

# --- Brötchen: Residuenverteilung ---
axes[0, 1].hist(resid_lstm_wg2, bins=40, color="tab:green", alpha=0.7, edgecolor="white")
axes[0, 1].axvline(0, linestyle="--", color="gray")
axes[0, 1].set_title("Residuenverteilung – LSTM Brötchen (WG2)")
axes[0, 1].set_xlabel("Residuum (EUR)")
axes[0, 1].set_ylabel("Häufigkeit")

# --- Kuchen: Residuen über die Zeit ---
axes[1, 0].plot(test_dates_wg5, resid_lstm_wg5, color="tab:orange", alpha=0.7)
axes[1, 0].axhline(0, linestyle="--", color="gray")
axes[1, 0].set_title("Residuen über die Zeit – LSTM Kuchen (WG5)")
axes[1, 0].set_xlabel("Datum")
axes[1, 0].set_ylabel("Residuum (EUR)")

# --- Kuchen: Residuenverteilung ---
axes[1, 1].hist(resid_lstm_wg5, bins=40, color="tab:orange", alpha=0.7, edgecolor="white")
axes[1, 1].axvline(0, linestyle="--", color="gray")
axes[1, 1].set_title("Residuenverteilung – LSTM Kuchen (WG5)")
axes[1, 1].set_xlabel("Residuum (EUR)")
axes[1, 1].set_ylabel("Häufigkeit")

plt.tight_layout()
plt.show()

# --- Actual vs Predicted Plot ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(test_dates_wg2, y_true_lstm_wg2, label="Tatsächlich", alpha=0.7)
axes[0].plot(test_dates_wg2, y_pred_lstm_wg2, label="LSTM Prognose", alpha=0.7)
axes[0].set_title("Tatsächlich vs. LSTM Prognose – Brötchen (WG2)")
axes[0].set_xlabel("Datum")
axes[0].set_ylabel("Umsatz (EUR)")
axes[0].legend()

axes[1].plot(test_dates_wg5, y_true_lstm_wg5, label="Tatsächlich", alpha=0.7)
axes[1].plot(test_dates_wg5, y_pred_lstm_wg5, label="LSTM Prognose", alpha=0.7)
axes[1].set_title("Tatsächlich vs. LSTM Prognose – Kuchen (WG5)")
axes[1].set_xlabel("Datum")
axes[1].set_ylabel("Umsatz (EUR)")
axes[1].legend()

plt.tight_layout()
plt.show()
